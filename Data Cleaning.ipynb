# %%
import pandas as pd

# %%
data_frame=pd.read_csv('data/new_train_data.csv')

# %%
data_frame.head()
# Out:
#           session_id  index  elapsed_time          event_name       name  \
# 0  20090312431273200     28         28113      navigate_click  undefined
# 1  20090312431273200     29         32229  notification_click      basic
# 2  20090312431273200     30         33063  notification_click      basic
# 3  20090312431273200     31         34245  notification_click      basic
# 4  20090312431273200     32         36433        object_click      close
#
#    level  page  room_coor_x  room_coor_y  screen_coor_x  ...  hover_duration  \
# 0      1   NaN  -587.657879   -27.916913          441.0  ...             NaN
# 1      1   NaN  -182.558163    -1.906501          767.0  ...             NaN
# 2      1   NaN  -182.500704   -55.888296          767.0  ...             NaN
# 3      1   NaN  -182.486523   -55.883804          767.0  ...             NaN
# 4      1   NaN  -113.484832   241.116732          836.0  ...             NaN
#
#                                       text               fqid  \
# 0                                      NaN  retirement_letter
# 1  Gramps is in trouble for losing papers?                NaN
# 2                     This can't be right!                NaN
# 3             Gramps is a great historian!                NaN
# 4                                      NaN  retirement_letter
#
#                         room_fqid  \
# 0  tunic.historicalsociety.closet
# 1  tunic.historicalsociety.closet
# 2  tunic.historicalsociety.closet
# 3  tunic.historicalsociety.closet
# 4  tunic.historicalsociety.closet
#
#                                            text_fqid fullscreen  hq  music  \
# 0                                                NaN          0   0      1
# 1  tunic.historicalsociety.closet.retirement_lett...          0   0      1
# 2  tunic.historicalsociety.closet.retirement_lett...          0   0      1
# 3  tunic.historicalsociety.closet.retirement_lett...          0   0      1
# 4                                                NaN          0   0      1
#
#    level_group correct
# 0          0-4       1
# 1          0-4       1
# 2          0-4       1
# 3          0-4       1
# 4          0-4       1
#
# [5 rows x 21 columns]

# %%
fqid_data=data_frame[['level','index','event_name','name','fqid','room_fqid','text_fqid']].copy()

# %%
fqid_data['extracted_fqid']=fqid_data['text_fqid'].str.split('.').str[3:].str.join('.')

# %%
#checking the records where fqid is null and text_fqid is not
text_fqid_nn=fqid_data[fqid_data['fqid'].isna()&(fqid_data['text_fqid'].isna()==False)]
text_fqid_nn
# Out:
#           level  index          event_name   name fqid  \
# 1             1     29  notification_click  basic  NaN
# 2             1     30  notification_click  basic  NaN
# 3             1     31  notification_click  basic  NaN
# 57            2     85  notification_click  basic  NaN
# 58            2     86  notification_click  basic  NaN
# ...         ...    ...                 ...    ...  ...
# 20731908     10    609  notification_click  basic  NaN
# 20732081     11    782  notification_click  basic  NaN
# 20732082     11    783  notification_click  basic  NaN
# 20732083     11    784  notification_click  basic  NaN
# 20732528     18   1274  notification_click  basic  NaN
#
#                                    room_fqid  \
# 1             tunic.historicalsociety.closet
# 2             tunic.historicalsociety.closet
# 3             tunic.historicalsociety.closet
# 57        tunic.historicalsociety.collection
# 58        tunic.historicalsociety.collection
# ...                                      ...
# 20731908             tunic.library.frontdesk
# 20732081      tunic.historicalsociety.stacks
# 20732082      tunic.historicalsociety.stacks
# 20732083      tunic.historicalsociety.stacks
# 20732528               tunic.wildlife.center
#
#                                                   text_fqid  \
# 1         tunic.historicalsociety.closet.retirement_lett...
# 2         tunic.historicalsociety.closet.retirement_lett...
# 3         tunic.historicalsociety.closet.retirement_lett...
# 57            tunic.historicalsociety.collection.tunic.slip
# 58            tunic.historicalsociety.collection.tunic.slip
# ...                                                     ...
# 20731908             tunic.library.frontdesk.wellsbadge.hub
# 20732081  tunic.historicalsociety.stacks.journals.pic_2....
# 20732082  tunic.historicalsociety.stacks.journals.pic_2....
# 20732083  tunic.historicalsociety.stacks.journals.pic_2....
# 20732528              tunic.wildlife.center.tracks.hub.deer
#
#                  extracted_fqid
# 1         retirement_letter.hub
# 2         retirement_letter.hub
# 3         retirement_letter.hub
# 57                   tunic.slip
# 58                   tunic.slip
# ...                         ...
# 20731908         wellsbadge.hub
# 20732081   journals.pic_2.bingo
# 20732082   journals.pic_2.bingo
# 20732083   journals.pic_2.bingo
# 20732528        tracks.hub.deer
#
# [420476 rows x 8 columns]

# %%
#filling the null values for extracted_fqid
fqid_data['extracted_fqid']=fqid_data['fqid']
fqid_data['extracted_fqid'].iloc[text_fqid_nn.index]=text_fqid_nn['extracted_fqid']
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
fqid_data.head()
# Out:
#    level  index          event_name       name               fqid  \
# 0      1     28      navigate_click  undefined  retirement_letter
# 1      1     29  notification_click      basic                NaN
# 2      1     30  notification_click      basic                NaN
# 3      1     31  notification_click      basic                NaN
# 4      1     32        object_click      close  retirement_letter
#
#                         room_fqid  \
# 0  tunic.historicalsociety.closet
# 1  tunic.historicalsociety.closet
# 2  tunic.historicalsociety.closet
# 3  tunic.historicalsociety.closet
# 4  tunic.historicalsociety.closet
#
#                                            text_fqid         extracted_fqid
# 0                                                NaN      retirement_letter
# 1  tunic.historicalsociety.closet.retirement_lett...  retirement_letter.hub
# 2  tunic.historicalsociety.closet.retirement_lett...  retirement_letter.hub
# 3  tunic.historicalsociety.closet.retirement_lett...  retirement_letter.hub
# 4                                                NaN      retirement_letter

# %%
fqid_data['extracted_text_fqid']=fqid_data['text_fqid']
e_tfqid_index=fqid_data[(fqid_data['extracted_fqid'].isna()==False)].index

# %%
ex_text_fqid_index=fqid_data[(fqid_data['text_fqid'].isna())&(fqid_data['extracted_fqid'].isna()==False)].index

# %%
fqid_data['extracted_text_fqid'].iloc[ex_text_fqid_index]=fqid_data['room_fqid'].iloc[ex_text_fqid_index]+'.'+fqid_data['extracted_fqid'].iloc[ex_text_fqid_index]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
fqid_data['combine']=fqid_data['event_name']+fqid_data['name']+fqid_data['room_fqid']+fqid_data['level'].astype(str)

# %%
fqid_data['combine_copy']=fqid_data['extracted_fqid']

# %%
sample_data=fqid_data[['event_name','name','room_fqid','extracted_text_fqid','fqid','level']]
sample_data_uni=sample_data.drop_duplicates()

# %%
fqid_dict=dict()
sample_data_uni['combine']=sample_data_uni['event_name']+sample_data_uni['name']+sample_data_uni['room_fqid']+sample_data_uni['level'].astype(str)
sample_data_uni=sample_data_uni[sample_data_uni['fqid'].isna()==False]
for comb in sample_data_uni.drop_duplicates()['combine'].unique():
    if len(sample_data_uni[sample_data_uni['combine']==comb]['fqid'].unique())==1:
        print(comb)
        print('---------')
        print(sample_data_uni[sample_data_uni['combine']==comb]['fqid'].unique())
        print('----------------------------------------------------------------------')
        fqid_dict[comb]=sample_data_uni[sample_data_uni['combine']==comb]['fqid'].unique()[0]
# Out:
# /var/folders/4b/082wp8yj1vdb15yd5756bphm0000gn/T/ipykernel_80787/2973587377.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_data_uni['combine']=sample_data_uni['event_name']+sample_data_uni['name']+sample_data_uni['room_fqid']+sample_data_uni['level'].astype(str)
# object_clickclosetunic.historicalsociety.closet1
# ---------
# ['retirement_letter']
# ----------------------------------------------------------------------
# observation_clickbasictunic.historicalsociety.basement1
# ---------
# ['janitor']
# ----------------------------------------------------------------------
# cutscene_clickbasictunic.historicalsociety.entry1
# ---------
# ['groupconvo']
# ----------------------------------------------------------------------
# object_clickclosetunic.historicalsociety.entry2
# ---------
# ['directory']
# ----------------------------------------------------------------------
# cutscene_clickbasictunic.historicalsociety.collection2
# ---------
# ['cs']
# ----------------------------------------------------------------------
# object_hoverundefinedtunic.historicalsociety.collection2
# ---------
# ['tunic.hub.slip']
# ----------------------------------------------------------------------
# object_clickclosetunic.historicalsociety.collection2
# ---------
# ['tunic']
# ----------------------------------------------------------------------
# person_clickbasictunic.historicalsociety.collection2
# ---------
# ['gramps']
# ----------------------------------------------------------------------
# observation_clickbasictunic.historicalsociety.stacks3
# ---------
# ['outtolunch']
# ----------------------------------------------------------------------
# observation_clickbasictunic.historicalsociety.basement3
# ---------
# ['janitor']
# ----------------------------------------------------------------------
# person_clickbasictunic.historicalsociety.closet3
# ---------
# ['teddy']
# ----------------------------------------------------------------------
# object_hoverundefinedtunic.kohlcenter.halloffame3
# ---------
# ['plaque.face.date']
# ----------------------------------------------------------------------
# object_clickclosetunic.kohlcenter.halloffame3
# ---------
# ['plaque']
# ----------------------------------------------------------------------
# cutscene_clickbasictunic.kohlcenter.halloffame3
# ---------
# ['togrampa']
# ----------------------------------------------------------------------
# checkpointbasictunic.capitol_0.hall4
# ---------
# ['chap1_finale_c']
# ----------------------------------------------------------------------
# person_clickbasictunic.capitol_0.hall5
# ---------
# ['boss']
# ----------------------------------------------------------------------
# cutscene_clickbasictunic.historicalsociety.closet_dirty5
# ---------
# ['what_happened']
# ----------------------------------------------------------------------
# person_clickbasictunic.historicalsociety.closet_dirty6
# ---------
# ['gramps']
# ----------------------------------------------------------------------
# person_clickbasictunic.historicalsociety.frontdesk6
# ---------
# ['archivist']
# ----------------------------------------------------------------------
# person_clickbasictunic.historicalsociety.frontdesk7
# ---------
# ['archivist']
# ----------------------------------------------------------------------
# person_clickbasictunic.humanecology.frontdesk7
# ---------
# ['worker']
# ----------------------------------------------------------------------
# object_clickclosetunic.humanecology.frontdesk7
# ---------
# ['businesscards']
# ----------------------------------------------------------------------
# person_clickbasictunic.humanecology.frontdesk8
# ---------
# ['worker']
# ----------------------------------------------------------------------
# person_clickbasictunic.drycleaner.frontdesk8
# ---------
# ['worker']
# ----------------------------------------------------------------------
# object_hoverundefinedtunic.drycleaner.frontdesk8
# ---------
# ['logbook.page.bingo']
# ----------------------------------------------------------------------
# object_clickclosetunic.drycleaner.frontdesk8
# ---------
# ['logbook']
# ----------------------------------------------------------------------
# person_clickbasictunic.drycleaner.frontdesk9
# ---------
# ['worker']
# ----------------------------------------------------------------------
# person_clickbasictunic.library.frontdesk9
# ---------
# ['worker']
# ----------------------------------------------------------------------
# object_clickclosetunic.library.microfiche9
# ---------
# ['reader']
# ----------------------------------------------------------------------
# object_clickclosetunic.library.frontdesk10
# ---------
# ['wellsbadge']
# ----------------------------------------------------------------------
# person_clickbasictunic.library.frontdesk10
# ---------
# ['worker']
# ----------------------------------------------------------------------
# person_clickbasictunic.capitol_1.hall11
# ---------
# ['boss']
# ----------------------------------------------------------------------
# person_clickbasictunic.historicalsociety.frontdesk11
# ---------
# ['archivist']
# ----------------------------------------------------------------------
# object_clickclosetunic.historicalsociety.stacks11
# ---------
# ['journals']
# ----------------------------------------------------------------------
# checkpointbasictunic.capitol_1.hall12
# ---------
# ['chap2_finale_c']
# ----------------------------------------------------------------------
# person_clickbasictunic.historicalsociety.basement13
# ---------
# ['gramps']
# ----------------------------------------------------------------------
# object_hoverundefinedtunic.historicalsociety.entry15
# ---------
# ['directory.closeup.archivist']
# ----------------------------------------------------------------------
# object_clickclosetunic.historicalsociety.entry15
# ---------
# ['directory']
# ----------------------------------------------------------------------
# observation_clickbasictunic.historicalsociety.frontdesk15
# ---------
# ['key']
# ----------------------------------------------------------------------
# navigate_clickundefinedtunic.historicalsociety.frontdesk16
# ---------
# ['tostacks']
# ----------------------------------------------------------------------
# cutscene_clickbasictunic.historicalsociety.basement17
# ---------
# ['savedteddy']
# ----------------------------------------------------------------------
# person_clickbasictunic.historicalsociety.collection_flag17
# ---------
# ['gramps']
# ----------------------------------------------------------------------
# cutscene_clickbasictunic.historicalsociety.entry18
# ---------
# ['groupconvo_flag']
# ----------------------------------------------------------------------
# object_hoverundefinedtunic.wildlife.center18
# ---------
# ['tracks.hub.deer']
# ----------------------------------------------------------------------
# object_clickclosetunic.wildlife.center18
# ---------
# ['tracks']
# ----------------------------------------------------------------------
# observation_clickbasictunic.historicalsociety.stacks5
# ---------
# ['outtolunch']
# ----------------------------------------------------------------------
# observation_clickbasictunic.historicalsociety.basement5
# ---------
# ['janitor']
# ----------------------------------------------------------------------
# object_clickclosetunic.library.microfiche11
# ---------
# ['reader']
# ----------------------------------------------------------------------
# object_clickbasictunic.historicalsociety.entry11
# ---------
# ['directory']
# ----------------------------------------------------------------------
# object_clickclosetunic.historicalsociety.entry11
# ---------
# ['directory']
# ----------------------------------------------------------------------
# observation_clickbasictunic.historicalsociety.cage14
# ---------
# ['lockeddoor']
# ----------------------------------------------------------------------
# object_hoverundefinedtunic.historicalsociety.entry17
# ---------
# ['directory.closeup.archivist']
# ----------------------------------------------------------------------
# object_clickclosetunic.historicalsociety.entry17
# ---------
# ['directory']
# ----------------------------------------------------------------------
# person_clickbasictunic.humanecology.frontdesk17
# ---------
# ['worker']
# ----------------------------------------------------------------------
# person_clickbasictunic.capitol_2.hall17
# ---------
# ['boss']
# ----------------------------------------------------------------------
# navigate_clickundefinedtunic.historicalsociety.frontdesk17
# ---------
# ['tostacks']
# ----------------------------------------------------------------------
# person_clickbasictunic.drycleaner.frontdesk17
# ---------
# ['worker']
# ----------------------------------------------------------------------
# person_clickbasictunic.library.frontdesk17
# ---------
# ['worker']
# ----------------------------------------------------------------------
# observation_clickbasictunic.historicalsociety.closet_dirty17
# ---------
# ['photo']
# ----------------------------------------------------------------------
# object_hoverbasictunic.kohlcenter.halloffame17
# ---------
# ['plaque']
# ----------------------------------------------------------------------
# object_clickbasictunic.kohlcenter.halloffame17
# ---------
# ['plaque']
# ----------------------------------------------------------------------
# object_clickclosetunic.kohlcenter.halloffame17
# ---------
# ['plaque']
# ----------------------------------------------------------------------
# object_clickclosetunic.historicalsociety.stacks17
# ---------
# ['journals']
# ----------------------------------------------------------------------
# object_clickclosetunic.humanecology.frontdesk17
# ---------
# ['businesscards']
# ----------------------------------------------------------------------
# object_clickbasictunic.drycleaner.frontdesk17
# ---------
# ['logbook']
# ----------------------------------------------------------------------
# object_clickclosetunic.drycleaner.frontdesk17
# ---------
# ['logbook']
# ----------------------------------------------------------------------
# object_clickclosetunic.library.microfiche17
# ---------
# ['reader']
# ----------------------------------------------------------------------
# person_clickbasictunic.historicalsociety.collection_flag18
# ---------
# ['gramps']
# ----------------------------------------------------------------------
# object_clickbasictunic.historicalsociety.closet1
# ---------
# ['retirement_letter']
# ----------------------------------------------------------------------
# object_clickbasictunic.library.frontdesk10
# ---------
# ['wellsbadge']
# ----------------------------------------------------------------------
# person_clickbasictunic.historicalsociety.collection3
# ---------
# ['gramps']
# ----------------------------------------------------------------------
# observation_clickbasictunic.historicalsociety.closet_dirty6
# ---------
# ['photo']
# ----------------------------------------------------------------------
# observation_clickbasictunic.historicalsociety.basement6
# ---------
# ['janitor']
# ----------------------------------------------------------------------
# object_clickclosetunic.humanecology.frontdesk8
# ---------
# ['businesscards']
# ----------------------------------------------------------------------
# person_clickbasictunic.library.frontdesk11
# ---------
# ['worker']
# ----------------------------------------------------------------------
# cutscene_clickbasictunic.capitol_1.hall12
# ---------
# ['chap2_finale_c']
# ----------------------------------------------------------------------
# person_clickbasictunic.capitol_1.hall13
# ---------
# ['boss']
# ----------------------------------------------------------------------
# object_hoverbasictunic.historicalsociety.collection13
# ---------
# ['tunic']
# ----------------------------------------------------------------------
# object_hoverundefinedtunic.historicalsociety.collection13
# ---------
# ['tunic.hub.slip']
# ----------------------------------------------------------------------
# object_clickclosetunic.historicalsociety.collection13
# ---------
# ['tunic']
# ----------------------------------------------------------------------
# object_clickclosetunic.historicalsociety.entry3
# ---------
# ['directory']
# ----------------------------------------------------------------------
# object_hoverbasictunic.kohlcenter.halloffame3
# ---------
# ['plaque']
# ----------------------------------------------------------------------
# observation_clickbasictunic.historicalsociety.stacks11
# ---------
# ['block']
# ----------------------------------------------------------------------
# observation_clickbasictunic.historicalsociety.entry2
# ---------
# ['block_tomap2']
# ----------------------------------------------------------------------
# object_hoverundefinedtunic.historicalsociety.entry18
# ---------
# ['directory.closeup.archivist']
# ----------------------------------------------------------------------
# object_clickclosetunic.historicalsociety.entry18
# ---------
# ['directory']
# ----------------------------------------------------------------------
# navigate_clickundefinedtunic.historicalsociety.frontdesk18
# ---------
# ['tostacks']
# ----------------------------------------------------------------------
# object_clickbasictunic.historicalsociety.entry3
# ---------
# ['directory']
# ----------------------------------------------------------------------
# object_clickclosetunic.humanecology.frontdesk11
# ---------
# ['businesscards']
# ----------------------------------------------------------------------
# observation_clickbasictunic.historicalsociety.closet_dirty18
# ---------
# ['photo']
# ----------------------------------------------------------------------
# person_clickbasictunic.drycleaner.frontdesk18
# ---------
# ['worker']
# ----------------------------------------------------------------------
# person_clickbasictunic.library.frontdesk18
# ---------
# ['worker']
# ----------------------------------------------------------------------
# object_clickclosetunic.library.microfiche18
# ---------
# ['reader']
# ----------------------------------------------------------------------
# object_hoverbasictunic.kohlcenter.halloffame18
# ---------
# ['plaque']
# ----------------------------------------------------------------------
# object_clickbasictunic.kohlcenter.halloffame18
# ---------
# ['plaque']
# ----------------------------------------------------------------------
# object_clickclosetunic.kohlcenter.halloffame18
# ---------
# ['plaque']
# ----------------------------------------------------------------------
# person_clickbasictunic.humanecology.frontdesk18
# ---------
# ['worker']
# ----------------------------------------------------------------------
# object_clickclosetunic.humanecology.frontdesk18
# ---------
# ['businesscards']
# ----------------------------------------------------------------------
# observation_clickbasictunic.historicalsociety.basement12
# ---------
# ['janitor']
# ----------------------------------------------------------------------
# person_clickbasictunic.historicalsociety.basement14
# ---------
# ['gramps']
# ----------------------------------------------------------------------
# object_hoverundefinedtunic.historicalsociety.collection14
# ---------
# ['tunic.hub.slip']
# ----------------------------------------------------------------------
# object_clickclosetunic.historicalsociety.collection14
# ---------
# ['tunic']
# ----------------------------------------------------------------------
# observation_clickbasictunic.historicalsociety.stacks14
# ---------
# ['outtolunch']
# ----------------------------------------------------------------------
# observation_clickbasictunic.historicalsociety.closet3
# ---------
# ['photo']
# ----------------------------------------------------------------------
# object_clickclosetunic.historicalsociety.closet3
# ---------
# ['retirement_letter']
# ----------------------------------------------------------------------
# person_clickbasictunic.capitol_1.hall9
# ---------
# ['boss']
# ----------------------------------------------------------------------
# person_clickbasictunic.capitol_2.hall15
# ---------
# ['boss']
# ----------------------------------------------------------------------
# person_clickbasictunic.drycleaner.frontdesk15
# ---------
# ['worker']
# ----------------------------------------------------------------------
# object_clickclosetunic.drycleaner.frontdesk15
# ---------
# ['logbook']
# ----------------------------------------------------------------------
# object_clickclosetunic.historicalsociety.stacks15
# ---------
# ['journals']
# ----------------------------------------------------------------------
# navigate_clickundefinedtunic.historicalsociety.collection_flag15
# ---------
# ['toentry']
# ----------------------------------------------------------------------
# person_clickbasictunic.capitol_2.hall18
# ---------
# ['boss']
# ----------------------------------------------------------------------
# object_clickclosetunic.historicalsociety.entry6
# ---------
# ['directory']
# ----------------------------------------------------------------------
# person_clickbasictunic.historicalsociety.closet_dirty12
# ---------
# ['gramps']
# ----------------------------------------------------------------------
# observation_clickbasictunic.historicalsociety.frontdesk14
# ---------
# ['key']
# ----------------------------------------------------------------------
# observation_clickbasictunic.historicalsociety.cage17
# ---------
# ['need_glasses']
# ----------------------------------------------------------------------
# person_clickbasictunic.historicalsociety.cage17
# ---------
# ['glasses']
# ----------------------------------------------------------------------
# object_clickclosetunic.library.microfiche10
# ---------
# ['reader']
# ----------------------------------------------------------------------
# object_clickclosetunic.historicalsociety.collection5
# ---------
# ['tunic']
# ----------------------------------------------------------------------
# object_clickclosetunic.kohlcenter.halloffame5
# ---------
# ['plaque']
# ----------------------------------------------------------------------
# object_clickclosetunic.historicalsociety.stacks12
# ---------
# ['journals']
# ----------------------------------------------------------------------
# observation_clickbasictunic.historicalsociety.closet_dirty15
# ---------
# ['photo']
# ----------------------------------------------------------------------
# person_clickbasictunic.humanecology.frontdesk11
# ---------
# ['worker']
# ----------------------------------------------------------------------
# person_clickbasictunic.historicalsociety.closet_dirty11
# ---------
# ['gramps']
# ----------------------------------------------------------------------
# person_clickbasictunic.library.frontdesk12
# ---------
# ['worker']
# ----------------------------------------------------------------------
# object_hoverbasictunic.kohlcenter.halloffame12
# ---------
# ['plaque']
# ----------------------------------------------------------------------
# object_clickbasictunic.kohlcenter.halloffame12
# ---------
# ['plaque']
# ----------------------------------------------------------------------
# object_clickclosetunic.kohlcenter.halloffame12
# ---------
# ['plaque']
# ----------------------------------------------------------------------
# person_clickbasictunic.library.frontdesk15
# ---------
# ['worker']
# ----------------------------------------------------------------------
# object_hoverbasictunic.library.microfiche17
# ---------
# ['reader']
# ----------------------------------------------------------------------
# object_clickbasictunic.historicalsociety.entry2
# ---------
# ['directory']
# ----------------------------------------------------------------------
# object_hoverundefinedtunic.historicalsociety.collection5
# ---------
# ['tunic.hub.slip']
# ----------------------------------------------------------------------
# observation_clickbasictunic.historicalsociety.basement2
# ---------
# ['janitor']
# ----------------------------------------------------------------------
# object_clickclosetunic.historicalsociety.collection3
# ---------
# ['tunic']
# ----------------------------------------------------------------------
# cutscene_clickbasictunic.capitol_0.hall4
# ---------
# ['chap1_finale_c']
# ----------------------------------------------------------------------
# object_clickbasictunic.kohlcenter.halloffame6
# ---------
# ['plaque']
# ----------------------------------------------------------------------
# object_clickclosetunic.kohlcenter.halloffame6
# ---------
# ['plaque']
# ----------------------------------------------------------------------
# person_clickbasictunic.humanecology.frontdesk15
# ---------
# ['worker']
# ----------------------------------------------------------------------
# object_clickclosetunic.historicalsociety.collection6
# ---------
# ['tunic']
# ----------------------------------------------------------------------
# person_clickbasictunic.historicalsociety.closet_dirty7
# ---------
# ['gramps']
# ----------------------------------------------------------------------
# person_clickbasictunic.historicalsociety.frontdesk12
# ---------
# ['archivist']
# ----------------------------------------------------------------------
# object_clickbasictunic.historicalsociety.entry6
# ---------
# ['directory']
# ----------------------------------------------------------------------
# observation_clickbasictunic.historicalsociety.basement11
# ---------
# ['janitor']
# ----------------------------------------------------------------------
# person_clickbasictunic.humanecology.frontdesk9
# ---------
# ['worker']
# ----------------------------------------------------------------------
# person_clickbasictunic.humanecology.frontdesk12
# ---------
# ['worker']
# ----------------------------------------------------------------------
# person_clickbasictunic.drycleaner.frontdesk12
# ---------
# ['worker']
# ----------------------------------------------------------------------
# object_hoverundefinedtunic.historicalsociety.entry16
# ---------
# ['directory.closeup.archivist']
# ----------------------------------------------------------------------
# object_clickclosetunic.historicalsociety.entry16
# ---------
# ['directory']
# ----------------------------------------------------------------------
# observation_clickbasictunic.historicalsociety.stacks13
# ---------
# ['outtolunch']
# ----------------------------------------------------------------------
# object_clickclosetunic.historicalsociety.stacks13
# ---------
# ['journals']
# ----------------------------------------------------------------------
# person_clickbasictunic.historicalsociety.closet1
# ---------
# ['teddy']
# ----------------------------------------------------------------------
# observation_clickbasictunic.historicalsociety.closet2
# ---------
# ['photo']
# ----------------------------------------------------------------------
# person_clickbasictunic.historicalsociety.closet2
# ---------
# ['teddy']
# ----------------------------------------------------------------------
# observation_clickbasictunic.historicalsociety.basement7
# ---------
# ['janitor']
# ----------------------------------------------------------------------
# person_clickbasictunic.capitol_1.hall7
# ---------
# ['boss']
# ----------------------------------------------------------------------
# object_hoverbasictunic.kohlcenter.halloffame11
# ---------
# ['plaque']
# ----------------------------------------------------------------------
# object_clickclosetunic.kohlcenter.halloffame11
# ---------
# ['plaque']
# ----------------------------------------------------------------------
# person_clickbasictunic.drycleaner.frontdesk11
# ---------
# ['worker']
# ----------------------------------------------------------------------
# object_clickbasictunic.drycleaner.frontdesk11
# ---------
# ['logbook']
# ----------------------------------------------------------------------
# object_clickclosetunic.drycleaner.frontdesk11
# ---------
# ['logbook']
# ----------------------------------------------------------------------
# object_clickclosetunic.library.microfiche15
# ---------
# ['reader']
# ----------------------------------------------------------------------
# cutscene_clickbasictunic.library.frontdesk10
# ---------
# ['block_badge']
# ----------------------------------------------------------------------
# observation_clickbasictunic.historicalsociety.closet_dirty7
# ---------
# ['photo']
# ----------------------------------------------------------------------
# object_clickclosetunic.kohlcenter.halloffame15
# ---------
# ['plaque']
# ----------------------------------------------------------------------
# object_clickclosetunic.humanecology.frontdesk15
# ---------
# ['businesscards']
# ----------------------------------------------------------------------
# object_hoverbasictunic.kohlcenter.halloffame15
# ---------
# ['plaque']
# ----------------------------------------------------------------------
# observation_clickbasictunic.kohlcenter.halloffame3
# ---------
# ['block_0']
# ----------------------------------------------------------------------
# observation_clickbasictunic.historicalsociety.closet_dirty12
# ---------
# ['photo']
# ----------------------------------------------------------------------
# object_clickclosetunic.historicalsociety.entry13
# ---------
# ['directory']
# ----------------------------------------------------------------------
# object_clickclosetunic.historicalsociety.entry14
# ---------
# ['directory']
# ----------------------------------------------------------------------
# object_hoverbasictunic.historicalsociety.stacks14
# ---------
# ['journals']
# ----------------------------------------------------------------------
# object_clickclosetunic.historicalsociety.stacks14
# ---------
# ['journals']
# ----------------------------------------------------------------------
# person_clickbasictunic.capitol_2.hall14
# ---------
# ['boss']
# ----------------------------------------------------------------------
# person_clickbasictunic.drycleaner.frontdesk14
# ---------
# ['worker']
# ----------------------------------------------------------------------
# object_hoverundefinedtunic.historicalsociety.collection3
# ---------
# ['tunic.hub.slip']
# ----------------------------------------------------------------------
# navigate_clickundefinedtunic.historicalsociety.collection_flag16
# ---------
# ['toentry']
# ----------------------------------------------------------------------
# object_clickclosetunic.drycleaner.frontdesk18
# ---------
# ['logbook']
# ----------------------------------------------------------------------
# object_clickclosetunic.historicalsociety.stacks18
# ---------
# ['journals']
# ----------------------------------------------------------------------
# object_hoverundefinedtunic.historicalsociety.collection6
# ---------
# ['tunic.hub.slip']
# ----------------------------------------------------------------------
# object_hoverbasictunic.historicalsociety.collection11
# ---------
# ['tunic']
# ----------------------------------------------------------------------
# object_hoverundefinedtunic.historicalsociety.collection11
# ---------
# ['tunic.hub.slip']
# ----------------------------------------------------------------------
# object_clickclosetunic.historicalsociety.collection11
# ---------
# ['tunic']
# ----------------------------------------------------------------------
# observation_clickbasictunic.library.microfiche9
# ---------
# ['block_0']
# ----------------------------------------------------------------------
# object_hoverundefinedtunic.historicalsociety.collection7
# ---------
# ['tunic.hub.slip']
# ----------------------------------------------------------------------
# object_clickclosetunic.historicalsociety.collection7
# ---------
# ['tunic']
# ----------------------------------------------------------------------
# object_clickclosetunic.historicalsociety.entry7
# ---------
# ['directory']
# ----------------------------------------------------------------------
# observation_clickbasictunic.historicalsociety.closet_dirty14
# ---------
# ['photo']
# ----------------------------------------------------------------------
# object_clickclosetunic.historicalsociety.stacks16
# ---------
# ['journals']
# ----------------------------------------------------------------------
# person_clickbasictunic.capitol_1.hall6
# ---------
# ['boss']
# ----------------------------------------------------------------------
# object_hoverundefinedtunic.historicalsociety.collection12
# ---------
# ['tunic.hub.slip']
# ----------------------------------------------------------------------
# object_clickclosetunic.historicalsociety.collection12
# ---------
# ['tunic']
# ----------------------------------------------------------------------
# object_clickclosetunic.historicalsociety.entry5
# ---------
# ['directory']
# ----------------------------------------------------------------------
# object_clickclosetunic.drycleaner.frontdesk9
# ---------
# ['logbook']
# ----------------------------------------------------------------------
# person_clickbasictunic.historicalsociety.closet_dirty9
# ---------
# ['gramps']
# ----------------------------------------------------------------------
# observation_clickbasictunic.historicalsociety.basement9
# ---------
# ['janitor']
# ----------------------------------------------------------------------
# object_clickbasictunic.kohlcenter.halloffame9
# ---------
# ['plaque']
# ----------------------------------------------------------------------
# object_clickclosetunic.kohlcenter.halloffame9
# ---------
# ['plaque']
# ----------------------------------------------------------------------
# person_clickbasictunic.historicalsociety.frontdesk9
# ---------
# ['archivist']
# ----------------------------------------------------------------------
# object_hoverundefinedtunic.historicalsociety.collection9
# ---------
# ['tunic.hub.slip']
# ----------------------------------------------------------------------
# object_clickclosetunic.historicalsociety.collection9
# ---------
# ['tunic']
# ----------------------------------------------------------------------
# observation_clickbasictunic.historicalsociety.closet_dirty9
# ---------
# ['photo']
# ----------------------------------------------------------------------
# object_clickbasictunic.drycleaner.frontdesk9
# ---------
# ['logbook']
# ----------------------------------------------------------------------
# object_clickclosetunic.library.microfiche12
# ---------
# ['reader']
# ----------------------------------------------------------------------
# object_clickclosetunic.drycleaner.frontdesk12
# ---------
# ['logbook']
# ----------------------------------------------------------------------
# person_clickbasictunic.capitol_2.hall16
# ---------
# ['boss']
# ----------------------------------------------------------------------
# observation_clickbasictunic.historicalsociety.closet_dirty11
# ---------
# ['photo']
# ----------------------------------------------------------------------
# object_clickbasictunic.historicalsociety.entry12
# ---------
# ['directory']
# ----------------------------------------------------------------------
# object_clickclosetunic.historicalsociety.entry12
# ---------
# ['directory']
# ----------------------------------------------------------------------
# object_clickclosetunic.kohlcenter.halloffame4
# ---------
# ['plaque']
# ----------------------------------------------------------------------
# person_clickbasictunic.library.frontdesk16
# ---------
# ['worker']
# ----------------------------------------------------------------------
# person_clickbasictunic.drycleaner.frontdesk16
# ---------
# ['worker']
# ----------------------------------------------------------------------
# object_clickbasictunic.drycleaner.frontdesk16
# ---------
# ['logbook']
# ----------------------------------------------------------------------
# object_clickclosetunic.drycleaner.frontdesk16
# ---------
# ['logbook']
# ----------------------------------------------------------------------
# observation_clickbasictunic.historicalsociety.stacks2
# ---------
# ['outtolunch']
# ----------------------------------------------------------------------
# object_hoverbasictunic.kohlcenter.halloffame6
# ---------
# ['plaque']
# ----------------------------------------------------------------------
# object_clickbasictunic.historicalsociety.entry5
# ---------
# ['directory']
# ----------------------------------------------------------------------
# object_hoverbasictunic.library.microfiche11
# ---------
# ['reader']
# ----------------------------------------------------------------------
# person_clickbasictunic.library.frontdesk14
# ---------
# ['worker']
# ----------------------------------------------------------------------
# person_clickbasictunic.humanecology.frontdesk14
# ---------
# ['worker']
# ----------------------------------------------------------------------
# object_clickclosetunic.humanecology.frontdesk14
# ---------
# ['businesscards']
# ----------------------------------------------------------------------
# observation_clickbasictunic.library.frontdesk10
# ---------
# ['block_badge_2']
# ----------------------------------------------------------------------
# object_hoverbasictunic.humanecology.frontdesk15
# ---------
# ['businesscards']
# ----------------------------------------------------------------------
# observation_clickbasictunic.historicalsociety.closet1
# ---------
# ['photo']
# ----------------------------------------------------------------------
# observation_clickbasictunic.historicalsociety.closet_dirty16
# ---------
# ['photo']
# ----------------------------------------------------------------------
# person_clickbasictunic.humanecology.frontdesk13
# ---------
# ['worker']
# ----------------------------------------------------------------------
# object_clickbasictunic.drycleaner.frontdesk15
# ---------
# ['logbook']
# ----------------------------------------------------------------------
# object_clickbasictunic.historicalsociety.entry7
# ---------
# ['directory']
# ----------------------------------------------------------------------
# object_clickbasictunic.drycleaner.frontdesk18
# ---------
# ['logbook']
# ----------------------------------------------------------------------
# person_clickbasictunic.drycleaner.frontdesk13
# ---------
# ['worker']
# ----------------------------------------------------------------------
# object_clickbasictunic.kohlcenter.halloffame4
# ---------
# ['plaque']
# ----------------------------------------------------------------------
# object_clickbasictunic.kohlcenter.halloffame11
# ---------
# ['plaque']
# ----------------------------------------------------------------------
# object_clickbasictunic.historicalsociety.entry14
# ---------
# ['directory']
# ----------------------------------------------------------------------
# person_clickbasictunic.library.frontdesk13
# ---------
# ['worker']
# ----------------------------------------------------------------------
# person_clickbasictunic.capitol_1.hall8
# ---------
# ['boss']
# ----------------------------------------------------------------------
# person_clickbasictunic.historicalsociety.entry1
# ---------
# ['gramps']
# ----------------------------------------------------------------------
# object_clickclosetunic.library.microfiche14
# ---------
# ['reader']
# ----------------------------------------------------------------------
# object_clickclosetunic.drycleaner.frontdesk14
# ---------
# ['logbook']
# ----------------------------------------------------------------------
# navigate_clickundefinedtunic.historicalsociety.collection_flag14
# ---------
# ['toentry']
# ----------------------------------------------------------------------
# person_clickbasictunic.historicalsociety.cage18
# ---------
# ['glasses']
# ----------------------------------------------------------------------
# object_clickclosetunic.humanecology.frontdesk13
# ---------
# ['businesscards']
# ----------------------------------------------------------------------
# object_clickbasictunic.historicalsociety.entry13
# ---------
# ['directory']
# ----------------------------------------------------------------------
# object_clickbasictunic.kohlcenter.halloffame5
# ---------
# ['plaque']
# ----------------------------------------------------------------------
# object_clickclosetunic.humanecology.frontdesk9
# ---------
# ['businesscards']
# ----------------------------------------------------------------------
# person_clickbasictunic.historicalsociety.closet_dirty8
# ---------
# ['gramps']
# ----------------------------------------------------------------------
# observation_clickbasictunic.historicalsociety.basement8
# ---------
# ['janitor']
# ----------------------------------------------------------------------
# object_clickclosetunic.historicalsociety.closet2
# ---------
# ['retirement_letter']
# ----------------------------------------------------------------------
# object_clickbasictunic.historicalsociety.closet3
# ---------
# ['retirement_letter']
# ----------------------------------------------------------------------
# object_hoverbasictunic.kohlcenter.halloffame5
# ---------
# ['plaque']
# ----------------------------------------------------------------------
# object_clickclosetunic.library.microfiche13
# ---------
# ['reader']
# ----------------------------------------------------------------------
# object_hoverbasictunic.library.microfiche12
# ---------
# ['reader']
# ----------------------------------------------------------------------
# object_hoverbasictunic.library.microfiche14
# ---------
# ['reader']
# ----------------------------------------------------------------------
# object_clickbasictunic.historicalsociety.closet2
# ---------
# ['retirement_letter']
# ----------------------------------------------------------------------
# object_clickbasictunic.kohlcenter.halloffame15
# ---------
# ['plaque']
# ----------------------------------------------------------------------
# object_hoverbasictunic.kohlcenter.halloffame4
# ---------
# ['plaque']
# ----------------------------------------------------------------------
# object_hoverbasictunic.drycleaner.frontdesk16
# ---------
# ['logbook']
# ----------------------------------------------------------------------
# object_hoverbasictunic.library.microfiche16
# ---------
# ['reader']
# ----------------------------------------------------------------------
# object_clickclosetunic.library.microfiche16
# ---------
# ['reader']
# ----------------------------------------------------------------------
# object_clickclosetunic.humanecology.frontdesk16
# ---------
# ['businesscards']
# ----------------------------------------------------------------------
# person_clickbasictunic.humanecology.frontdesk16
# ---------
# ['worker']
# ----------------------------------------------------------------------
# object_hoverbasictunic.historicalsociety.closet2
# ---------
# ['retirement_letter']
# ----------------------------------------------------------------------
# object_hoverbasictunic.humanecology.frontdesk17
# ---------
# ['businesscards']
# ----------------------------------------------------------------------
# object_clickclosetunic.humanecology.frontdesk12
# ---------
# ['businesscards']
# ----------------------------------------------------------------------
# object_clickbasictunic.drycleaner.frontdesk12
# ---------
# ['logbook']
# ----------------------------------------------------------------------
# object_hoverbasictunic.historicalsociety.entry9
# ---------
# ['directory']
# ----------------------------------------------------------------------
# object_clickbasictunic.historicalsociety.entry9
# ---------
# ['directory']
# ----------------------------------------------------------------------
# object_clickclosetunic.historicalsociety.entry9
# ---------
# ['directory']
# ----------------------------------------------------------------------
# object_hoverbasictunic.humanecology.frontdesk14
# ---------
# ['businesscards']
# ----------------------------------------------------------------------
# object_clickbasictunic.drycleaner.frontdesk13
# ---------
# ['logbook']
# ----------------------------------------------------------------------
# object_clickclosetunic.drycleaner.frontdesk13
# ---------
# ['logbook']
# ----------------------------------------------------------------------
# object_hoverbasictunic.library.microfiche13
# ---------
# ['reader']
# ----------------------------------------------------------------------
# object_hoverundefinedtunic.historicalsociety.collection8
# ---------
# ['tunic.hub.slip']
# ----------------------------------------------------------------------
# object_clickclosetunic.historicalsociety.collection8
# ---------
# ['tunic']
# ----------------------------------------------------------------------
# person_clickbasictunic.historicalsociety.frontdesk8
# ---------
# ['archivist']
# ----------------------------------------------------------------------
# object_hoverbasictunic.humanecology.frontdesk13
# ---------
# ['businesscards']
# ----------------------------------------------------------------------
# object_clickbasictunic.kohlcenter.halloffame13
# ---------
# ['plaque']
# ----------------------------------------------------------------------
# object_hoverbasictunic.kohlcenter.halloffame13
# ---------
# ['plaque']
# ----------------------------------------------------------------------
# object_clickclosetunic.kohlcenter.halloffame13
# ---------
# ['plaque']
# ----------------------------------------------------------------------
# object_clickclosetunic.kohlcenter.halloffame7
# ---------
# ['plaque']
# ----------------------------------------------------------------------
# object_hoverbasictunic.humanecology.frontdesk12
# ---------
# ['businesscards']
# ----------------------------------------------------------------------
# object_hoverbasictunic.kohlcenter.halloffame16
# ---------
# ['plaque']
# ----------------------------------------------------------------------
# object_clickclosetunic.kohlcenter.halloffame16
# ---------
# ['plaque']
# ----------------------------------------------------------------------
# object_clickclosetunic.kohlcenter.halloffame14
# ---------
# ['plaque']
# ----------------------------------------------------------------------
# object_clickbasictunic.drycleaner.frontdesk14
# ---------
# ['logbook']
# ----------------------------------------------------------------------
# object_clickbasictunic.kohlcenter.halloffame14
# ---------
# ['plaque']
# ----------------------------------------------------------------------
# object_hoverbasictunic.humanecology.frontdesk9
# ---------
# ['businesscards']
# ----------------------------------------------------------------------
# object_clickbasictunic.kohlcenter.halloffame7
# ---------
# ['plaque']
# ----------------------------------------------------------------------
# object_hoverbasictunic.kohlcenter.halloffame14
# ---------
# ['plaque']
# ----------------------------------------------------------------------
# object_hoverbasictunic.kohlcenter.halloffame9
# ---------
# ['plaque']
# ----------------------------------------------------------------------
# person_clickbasictunic.capitol_2.hall13
# ---------
# ['boss']
# ----------------------------------------------------------------------
# object_clickclosetunic.historicalsociety.entry8
# ---------
# ['directory']
# ----------------------------------------------------------------------
# object_hoverbasictunic.historicalsociety.collection8
# ---------
# ['tunic']
# ----------------------------------------------------------------------
# observation_clickbasictunic.historicalsociety.closet_dirty8
# ---------
# ['photo']
# ----------------------------------------------------------------------
# object_hoverbasictunic.historicalsociety.entry8
# ---------
# ['directory']
# ----------------------------------------------------------------------
# object_clickbasictunic.historicalsociety.entry8
# ---------
# ['directory']
# ----------------------------------------------------------------------
# object_clickclosetunic.kohlcenter.halloffame8
# ---------
# ['plaque']
# ----------------------------------------------------------------------
# object_hoverbasictunic.humanecology.frontdesk16
# ---------
# ['businesscards']
# ----------------------------------------------------------------------
# object_clickbasictunic.kohlcenter.halloffame8
# ---------
# ['plaque']
# ----------------------------------------------------------------------
# object_clickbasictunic.kohlcenter.halloffame16
# ---------
# ['plaque']
# ----------------------------------------------------------------------

# %%
null_fqid_data=fqid_data[fqid_data['extracted_fqid'].isna()]['combine'].map(fqid_dict).index

# %%
fqid_data['combine_copy'].iloc[null_fqid_data]=fqid_data[fqid_data['extracted_fqid'].isna()]['combine'].map(fqid_dict)

# %%
fqid_data.head()
# Out:
#    level  index          event_name       name               fqid  \
# 0      1     28      navigate_click  undefined  retirement_letter
# 1      1     29  notification_click      basic                NaN
# 2      1     30  notification_click      basic                NaN
# 3      1     31  notification_click      basic                NaN
# 4      1     32        object_click      close  retirement_letter
#
#                         room_fqid  \
# 0  tunic.historicalsociety.closet
# 1  tunic.historicalsociety.closet
# 2  tunic.historicalsociety.closet
# 3  tunic.historicalsociety.closet
# 4  tunic.historicalsociety.closet
#
#                                            text_fqid         extracted_fqid  \
# 0                                                NaN      retirement_letter
# 1  tunic.historicalsociety.closet.retirement_lett...  retirement_letter.hub
# 2  tunic.historicalsociety.closet.retirement_lett...  retirement_letter.hub
# 3  tunic.historicalsociety.closet.retirement_lett...  retirement_letter.hub
# 4                                                NaN      retirement_letter
#
#                                  extracted_text_fqid  \
# 0   tunic.historicalsociety.closet.retirement_letter
# 1  tunic.historicalsociety.closet.retirement_lett...
# 2  tunic.historicalsociety.closet.retirement_lett...
# 3  tunic.historicalsociety.closet.retirement_lett...
# 4   tunic.historicalsociety.closet.retirement_letter
#
#                                              combine           combine_copy
# 0  navigate_clickundefinedtunic.historicalsociety...      retirement_letter
# 1  notification_clickbasictunic.historicalsociety...  retirement_letter.hub
# 2  notification_clickbasictunic.historicalsociety...  retirement_letter.hub
# 3  notification_clickbasictunic.historicalsociety...  retirement_letter.hub
# 4   object_clickclosetunic.historicalsociety.closet1      retirement_letter

# %%
cc_nn_index=fqid_data[fqid_data['extracted_text_fqid'].isna()&(fqid_data['combine_copy'].isna()==False)].index

# %%
fqid_data['extracted_text_fqid_copy']=fqid_data['extracted_text_fqid']

# %%
fqid_data['extracted_text_fqid_copy'].iloc[cc_nn_index]=fqid_data['room_fqid'].iloc[cc_nn_index]+'.'+fqid_data['combine_copy'].iloc[cc_nn_index]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
fqid_data.isnull().sum()
# Out:
# level                              0
# index                              0
# event_name                         0
# name                               0
# fqid                         6367237
# room_fqid                          0
# text_fqid                   12689791
# extracted_fqid               5946761
# extracted_text_fqid          5946761
# combine                            0
# combine_copy                 5882670
# extracted_text_fqid_copy     5882670
# dtype: int64
