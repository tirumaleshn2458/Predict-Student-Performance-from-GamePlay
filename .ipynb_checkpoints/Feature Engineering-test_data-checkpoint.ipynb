# %% [markdown]
# # Predict Student Performance using GamePlay
#
# ### Feature Engineering
#
# - session_id - the ID of the session the event took place in
# - index - the index of the event for the session
# - elapsed_time - how much time has passed (in milliseconds) between the start of the session and when the event was recorded
# - event_name - the name of the event type
# - name - the event name (e.g. identifies whether a notebook_click is is opening or closing the notebook)
# - level - what level of the game the event occurred in (0 to 22)
# - page - the page number of the event (only for notebook-related events)
# - room_coor_x - the coordinates of the click in reference to the in-game room (only for click events)
# - room_coor_y - the coordinates of the click in reference to the in-game room (only for click events)
# - screen_coor_x - the coordinates of the click in reference to the player’s screen (only for click events)
# - screen_coor_y - the coordinates of the click in reference to the player’s screen (only for click events)
# - hover_duration - how long (in milliseconds) the hover happened for (only for hover events)
# - text - the text the player sees during this event
# - fqid - the fully qualified ID of the event
# - room_fqid - the fully qualified ID of the room the event took place in
# - text_fqid - the fully qualified ID of the
# - fullscreen - whether the player is in fullscreen mode
# - hq - whether the game is in high-quality
# - music - whether the game music is on or off
# - level_group - which group of levels - and group of questions - this row belongs to (0-4, 5-12, 13-22)

# %%
#import libraries
import pandas as pd
import numpy as np

# %%
#reading the dataset
data_frame=pd.read_csv('data/test.csv')

# %%
data_frame.head()
# Out:
#           session_id  index  elapsed_time      event_name   name  level  page  \
# 0  20090109393214576      0             0  cutscene_click  basic      0   NaN
# 1  20090109393214576      1          1965    person_click  basic      0   NaN
# 2  20090109393214576      2          3614    person_click  basic      0   NaN
# 3  20090109393214576      3          5330    person_click  basic      0   NaN
# 4  20090109393214576      4          6397    person_click  basic      0   NaN
#
#    room_coor_x  room_coor_y  screen_coor_x  ...  hover_duration  \
# 0  -413.991405    75.685314          380.0  ...             NaN
# 1  -105.991405   -63.314686          688.0  ...             NaN
# 2  -418.991405    47.685314          375.0  ...             NaN
# 3  -110.991405   -57.314686          683.0  ...             NaN
# 4  -110.991405   -57.314686          683.0  ...             NaN
#
#                             text    fqid                       room_fqid  \
# 0                      undefined   intro  tunic.historicalsociety.closet
# 1  Whatcha doing over there, Jo?  gramps  tunic.historicalsociety.closet
# 2         Just talking to Teddy.  gramps  tunic.historicalsociety.closet
# 3     I gotta run to my meeting!  gramps  tunic.historicalsociety.closet
# 4            Can I come, Gramps?  gramps  tunic.historicalsociety.closet
#
#                                            text_fqid fullscreen  hq  music  \
# 0               tunic.historicalsociety.closet.intro          0   0      1
# 1  tunic.historicalsociety.closet.gramps.intro_0_...          0   0      1
# 2  tunic.historicalsociety.closet.gramps.intro_0_...          0   0      1
# 3  tunic.historicalsociety.closet.gramps.intro_0_...          0   0      1
# 4  tunic.historicalsociety.closet.gramps.intro_0_...          0   0      1
#
#    level_group session_level
# 0          0-4             0
# 1          0-4             0
# 2          0-4             0
# 3          0-4             0
# 4          0-4             0
#
# [5 rows x 21 columns]

# %%
data_frame.shape
# Out:
# (3728, 21)

# %% [markdown]
# ## Handling null values

# %%
data_frame.isnull().sum()
# Out:
# session_id           0
# index                0
# elapsed_time         0
# event_name           0
# name                 0
# level                0
# page              3575
# room_coor_x        362
# room_coor_y        362
# screen_coor_x      362
# screen_coor_y      362
# hover_duration    3375
# text              2566
# fqid              1223
# room_fqid            0
# text_fqid         2566
# fullscreen           0
# hq                   0
# music                0
# level_group          0
# session_level        0
# dtype: int64

# %% [markdown]
# #### Null values in page column

# %%
data_frame['page'].unique()
# Out:
# array([nan,  0.,  1.,  2.,  3.,  4.,  5.,  6.])

# %% [markdown]
# Getting the group of level values based on page number

# %%
data_frame.groupby('page')['event_name'].unique()
# Out:
# page
# 0.0    [notebook_click]
# 1.0    [notebook_click]
# 2.0    [notebook_click]
# 3.0    [notebook_click]
# 4.0    [notebook_click]
# 5.0    [notebook_click]
# 6.0    [notebook_click]
# Name: event_name, dtype: object

# %%
data_frame['event_name'].unique()
# Out:
# array(['cutscene_click', 'person_click', 'navigate_click',
#        'observation_click', 'notification_click', 'object_click',
#        'object_hover', 'notebook_click', 'map_hover', 'map_click',
#        'checkpoint'], dtype=object)

# %% [markdown]
# Page numbers are only for notebook_click (notebook related events). So, the page values for other values in event_name column are null. We need to fill null values in page column with the some other value probably -1. Since, event_name is discrete and has 0 in it.

# %%
data_frame['page']=data_frame['page'].fillna(-1)

# %%
data_frame['page'].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### Null values in coordinate columns

# %%
#there are 4 coordinate columns such as room_coor_x, room_coor_y, screen_coor_x and screen_coor_y

# %% [markdown]
# The coordinate values are only for click_events

# %%
#shape of dataframe where room_coor_x is not null
data_frame[data_frame['room_coor_x'].isna()==False].shape
# Out:
# (3366, 21)

# %%
#shape of dataframe where room_coor_x is null
data_frame[data_frame['room_coor_x'].isna()].shape
# Out:
# (362, 21)

# %%
#checking the null values for all the coordinate columns
data_frame[['room_coor_x','room_coor_y','screen_coor_x','screen_coor_y']].isnull().sum()
# Out:
# room_coor_x      362
# room_coor_y      362
# screen_coor_x    362
# screen_coor_y    362
# dtype: int64

# %%
#Below query shows that all the coordinate values are null if any coordinate value is null.

# %%
data_frame[data_frame['room_coor_x'].isna()&data_frame['room_coor_y'].isna()&
          data_frame['screen_coor_x'].isna()&data_frame['screen_coor_y'].isna()]
# Out:
#              session_id  index  elapsed_time    event_name       name  level  \
# 67    20090109393214576     67        116880  object_hover  undefined      2
# 96    20090109393214576     96        166545     map_hover      basic      3
# 109   20090109393214576    109        184627  object_hover  undefined      3
# 114   20090109393214576    114        190745  object_hover  undefined      3
# 136   20090109393214576    136        207212     map_hover      basic      4
# ...                 ...    ...           ...           ...        ...    ...
# 3721  20090312331414616    999       1580531     map_hover      basic     22
# 3722  20090312331414616   1000       1581029     map_hover      basic     22
# 3723  20090312331414616   1001       1581679     map_hover      basic     22
# 3724  20090312331414616   1002       1583044     map_hover      basic     22
# 3727  20090312331414616   1005       1587810    checkpoint      basic     22
#
#       page  room_coor_x  room_coor_y  screen_coor_x  ...  hover_duration  \
# 67    -1.0          NaN          NaN            NaN  ...          5168.0
# 96    -1.0          NaN          NaN            NaN  ...           132.0
# 109   -1.0          NaN          NaN            NaN  ...            33.0
# 114   -1.0          NaN          NaN            NaN  ...          3816.0
# 136   -1.0          NaN          NaN            NaN  ...           885.0
# ...    ...          ...          ...            ...  ...             ...
# 3721  -1.0          NaN          NaN            NaN  ...            35.0
# 3722  -1.0          NaN          NaN            NaN  ...            16.0
# 3723  -1.0          NaN          NaN            NaN  ...           484.0
# 3724  -1.0          NaN          NaN            NaN  ...           783.0
# 3727  -1.0          NaN          NaN            NaN  ...             NaN
#
#       text                     fqid                           room_fqid  \
# 67     NaN           tunic.hub.slip  tunic.historicalsociety.collection
# 96     NaN  tunic.historicalsociety       tunic.historicalsociety.entry
# 109    NaN         plaque.face.date         tunic.kohlcenter.halloffame
# 114    NaN         plaque.face.date         tunic.kohlcenter.halloffame
# 136    NaN                  toentry         tunic.kohlcenter.halloffame
# ...    ...                      ...                                 ...
# 3721   NaN       tunic.humanecology       tunic.historicalsociety.entry
# 3722   NaN       tunic.humanecology       tunic.historicalsociety.entry
# 3723   NaN           tunic.wildlife       tunic.historicalsociety.entry
# 3724   NaN          tunic.capitol_2       tunic.historicalsociety.entry
# 3727   NaN           chap4_finale_c                tunic.capitol_2.hall
#
#      text_fqid fullscreen  hq  music  level_group session_level
# 67         NaN          0   0      1          0-4             0
# 96         NaN          0   0      1          0-4             0
# 109        NaN          0   0      1          0-4             0
# 114        NaN          0   0      1          0-4             0
# 136        NaN          0   0      1          0-4             0
# ...        ...        ...  ..    ...          ...           ...
# 3721       NaN          0   0      1        13-22             8
# 3722       NaN          0   0      1        13-22             8
# 3723       NaN          0   0      1        13-22             8
# 3724       NaN          0   0      1        13-22             8
# 3727       NaN          0   0      1        13-22             8
#
# [362 rows x 21 columns]

# %% [markdown]
# Let us replace all the coordinate values with 0. Since, the coordinate value pair will 0,0.
# Before that, we will check whether there is (0,0) pair in coordinate columns.

# %%
#checking for room coordinates
data_frame[(data_frame['room_coor_x']==0)&(data_frame['room_coor_y']==0)]
# Out:
# Empty DataFrame
# Columns: [session_id, index, elapsed_time, event_name, name, level, page, room_coor_x, room_coor_y, screen_coor_x, screen_coor_y, hover_duration, text, fqid, room_fqid, text_fqid, fullscreen, hq, music, level_group, session_level]
# Index: []
#
# [0 rows x 21 columns]

# %%
#checking for screen coordinates
data_frame[(data_frame['screen_coor_x']==0)&(data_frame['screen_coor_y']==0)]
# Out:
# Empty DataFrame
# Columns: [session_id, index, elapsed_time, event_name, name, level, page, room_coor_x, room_coor_y, screen_coor_x, screen_coor_y, hover_duration, text, fqid, room_fqid, text_fqid, fullscreen, hq, music, level_group, session_level]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# We can conclude that there is no certain pair that is (0,0). So, we can replace 0 in all the null values in coordinate columns

# %%
data_frame['room_coor_x']=data_frame['room_coor_x'].fillna(0)
data_frame['room_coor_y']=data_frame['room_coor_y'].fillna(0)
data_frame['screen_coor_x']=data_frame['screen_coor_x'].fillna(0)
data_frame['screen_coor_y']=data_frame['screen_coor_y'].fillna(0)

# %%
#re-checking the null values for all the coordinate columns
data_frame.isnull().sum()
# Out:
# session_id           0
# index                0
# elapsed_time         0
# event_name           0
# name                 0
# level                0
# page                 0
# room_coor_x          0
# room_coor_y          0
# screen_coor_x        0
# screen_coor_y        0
# hover_duration    3375
# text              2566
# fqid              1223
# room_fqid            0
# text_fqid         2566
# fullscreen           0
# hq                   0
# music                0
# level_group          0
# session_level        0
# dtype: int64

# %% [markdown]
# Handling missing values for hover_duration column

# %%
0 in data_frame['hover_duration'].unique()
# Out:
# False

# %% [markdown]
# Let us replace 0 with the null values in the hover_duration column since, there will be no hover event to calculate the time

# %%
data_frame['hover_duration']=data_frame['hover_duration'].fillna(0)

# %%
data_frame.isnull().sum()
# Out:
# session_id           0
# index                0
# elapsed_time         0
# event_name           0
# name                 0
# level                0
# page                 0
# room_coor_x          0
# room_coor_y          0
# screen_coor_x        0
# screen_coor_y        0
# hover_duration       0
# text              2566
# fqid              1223
# room_fqid            0
# text_fqid         2566
# fullscreen           0
# hq                   0
# music                0
# level_group          0
# session_level        0
# dtype: int64

# %%
#the remaining columns are of object type

# %% [markdown]
# Replacing the null values for fqid, text_fqid is related to each other.

# %%
#getting the data_frame records with specific columns
fqid_data=data_frame[['level','index','event_name','name','fqid','room_fqid','text_fqid']].copy()

# %%
#filling the null values for extracted_fqid
#creating the new column extracted_fqid which will store the fqid column's values. 
fqid_data['extracted_fqid']=fqid_data['fqid']
#checking the records where fqid is null and text_fqid is not and storing
text_fqid_nn=fqid_data[fqid_data['fqid'].isna()&(fqid_data['text_fqid'].isna()==False)]

# %%
#assigning the values for extracted_fqid column with the extracted_fqid column's value in 
#text_fqid_nn dataframe with the text_fqid_nn index values.
fqid_data['extracted_fqid'].iloc[text_fqid_nn.index]=text_fqid_nn['extracted_fqid']
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
fqid_data.head()
# Out:
#    level  index      event_name   name    fqid  \
# 0      0      0  cutscene_click  basic   intro
# 1      0      1    person_click  basic  gramps
# 2      0      2    person_click  basic  gramps
# 3      0      3    person_click  basic  gramps
# 4      0      4    person_click  basic  gramps
#
#                         room_fqid  \
# 0  tunic.historicalsociety.closet
# 1  tunic.historicalsociety.closet
# 2  tunic.historicalsociety.closet
# 3  tunic.historicalsociety.closet
# 4  tunic.historicalsociety.closet
#
#                                            text_fqid extracted_fqid
# 0               tunic.historicalsociety.closet.intro          intro
# 1  tunic.historicalsociety.closet.gramps.intro_0_...         gramps
# 2  tunic.historicalsociety.closet.gramps.intro_0_...         gramps
# 3  tunic.historicalsociety.closet.gramps.intro_0_...         gramps
# 4  tunic.historicalsociety.closet.gramps.intro_0_...         gramps

# %%
#creating a new column named extracted_text_fqid and storing text_fqid column values.
fqid_data['extracted_text_fqid']=fqid_data['text_fqid']

# %%
#getting the index values of fqid_data where text_fqid has null values and extracted_fqid. doesn't null values..
ex_text_fqid_index=fqid_data[(fqid_data['text_fqid'].isna())&(fqid_data['extracted_fqid'].isna()==False)].index

# %%
#assigning the values i.e combination of room_fqid and extracted_fqid column values to extracted_text_fqid at the index values taken from above. 
fqid_data['extracted_text_fqid'].iloc[ex_text_fqid_index]=fqid_data['room_fqid'].iloc[ex_text_fqid_index]+'.'+fqid_data['extracted_fqid'].iloc[ex_text_fqid_index]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
#creating a new column combine by joining the values in event_name, name, room_fqid and level as a single string. 
fqid_data['combine']=fqid_data['event_name']+fqid_data['name']+fqid_data['room_fqid']+fqid_data['level'].astype(str)

# %%
#creating a new combine_copy and storing extracted_fqid column's values.
fqid_data['combine_copy']=fqid_data['extracted_fqid']

# %%
#taking limited columns event_name, name, room_fqid, extracted_text_fqid, 'extracted_fqid', level 
#to replace the null values of fqid column
sample_data=fqid_data[['event_name','name','room_fqid','extracted_text_fqid','extracted_fqid','level']]
#getting the records from the above dataframe where the extracted_fqid is null and dropping the duplicates in it.
sample_data_uni=sample_data[sample_data['extracted_fqid'].isna()==False].drop_duplicates()

# %%
#shape of above dataframe after dropping duplicates
sample_data_uni.shape
# Out:
# (541, 6)

# %%
#creating a dictionary to store the values of fqid
fqid_dict=dict()
#combining all the string values of event_name, name, room_fqid and level and storing in a new columm 'combine'
sample_data_uni['combine']=sample_data_uni['event_name']+sample_data_uni['name']+sample_data_uni['room_fqid']+sample_data_uni['level'].astype(str)
#iterating through the unique values of combine column 
for comb in sample_data_uni.drop_duplicates()['combine'].unique():
    #checking whether the extracted_fqid has only one unique value through each combine value
    if len(sample_data_uni[sample_data_uni['combine']==comb]['extracted_fqid'].unique())==1:
        #if yes, then printing the combine value and the extracted_fqid value
        print(comb)
        print('---------')
        print(sample_data_uni[sample_data_uni['combine']==comb]['extracted_fqid'].unique())
        print('----------------------------------------------------------------------')
        #assigning the extracted_fqid value to the fqid_dict where combine is the key
        fqid_dict[comb]=sample_data_uni[sample_data_uni['combine']==comb]['extracted_fqid'].unique()[0]
# Out:
# cutscene_clickbasictunic.historicalsociety.closet0
# ---------
# ['intro']
# ----------------------------------------------------------------------
# observation_clickbasictunic.historicalsociety.closet0
# ---------
# ['photo']
# ----------------------------------------------------------------------
# navigate_clickundefinedtunic.historicalsociety.closet1
# ---------
# ['tobasement']
# ----------------------------------------------------------------------
# observation_clickbasictunic.historicalsociety.basement1
# ---------
# ['janitor']
# ----------------------------------------------------------------------
# cutscene_clickbasictunic.historicalsociety.entry1
# ---------
# ['groupconvo']
# ----------------------------------------------------------------------
# object_clickbasictunic.historicalsociety.entry1
# ---------
# ['report']
# ----------------------------------------------------------------------
# object_clickclosetunic.historicalsociety.entry1
# ---------
# ['report']
# ----------------------------------------------------------------------
# cutscene_clickbasictunic.historicalsociety.collection2
# ---------
# ['cs']
# ----------------------------------------------------------------------
# object_hoverundefinedtunic.historicalsociety.collection2
# ---------
# ['tunic.hub.slip']
# ----------------------------------------------------------------------
# object_clickclosetunic.historicalsociety.collection2
# ---------
# ['tunic']
# ----------------------------------------------------------------------
# person_clickbasictunic.historicalsociety.collection2
# ---------
# ['gramps']
# ----------------------------------------------------------------------
# person_clickbasictunic.historicalsociety.collection3
# ---------
# ['gramps']
# ----------------------------------------------------------------------
# map_clickundefinedtunic.historicalsociety.entry3
# ---------
# ['tunic.kohlcenter']
# ----------------------------------------------------------------------
# navigate_clickundefinedtunic.kohlcenter.halloffame3
# ---------
# ['plaque']
# ----------------------------------------------------------------------
# object_hoverundefinedtunic.kohlcenter.halloffame3
# ---------
# ['plaque.face.date']
# ----------------------------------------------------------------------
# object_clickclosetunic.kohlcenter.halloffame3
# ---------
# ['plaque']
# ----------------------------------------------------------------------
# cutscene_clickbasictunic.kohlcenter.halloffame3
# ---------
# ['togrampa']
# ----------------------------------------------------------------------
# navigate_clickundefinedtunic.kohlcenter.halloffame4
# ---------
# ['toentry']
# ----------------------------------------------------------------------
# map_hoverbasictunic.kohlcenter.halloffame4
# ---------
# ['toentry']
# ----------------------------------------------------------------------
# map_clickundefinedtunic.kohlcenter.halloffame4
# ---------
# ['tunic.capitol_0']
# ----------------------------------------------------------------------
# navigate_clickundefinedtunic.capitol_0.hall4
# ---------
# ['chap1_finale']
# ----------------------------------------------------------------------
# checkpointbasictunic.capitol_0.hall4
# ---------
# ['chap1_finale_c']
# ----------------------------------------------------------------------
# map_clickundefinedtunic.capitol_0.hall5
# ---------
# ['tunic.historicalsociety']
# ----------------------------------------------------------------------
# navigate_clickundefinedtunic.historicalsociety.basement5
# ---------
# ['tocloset_dirty']
# ----------------------------------------------------------------------
# cutscene_clickbasictunic.historicalsociety.closet_dirty5
# ---------
# ['what_happened']
# ----------------------------------------------------------------------
# person_clickbasictunic.historicalsociety.closet_dirty6
# ---------
# ['gramps']
# ----------------------------------------------------------------------
# navigate_clickundefinedtunic.historicalsociety.basement6
# ---------
# ['toentry']
# ----------------------------------------------------------------------
# navigate_clickundefinedtunic.historicalsociety.collection6
# ---------
# ['toentry']
# ----------------------------------------------------------------------
# navigate_clickundefinedtunic.historicalsociety.stacks6
# ---------
# ['tofrontdesk']
# ----------------------------------------------------------------------
# person_clickbasictunic.historicalsociety.frontdesk6
# ---------
# ['archivist']
# ----------------------------------------------------------------------
# person_clickbasictunic.historicalsociety.frontdesk7
# ---------
# ['archivist']
# ----------------------------------------------------------------------
# navigate_clickundefinedtunic.historicalsociety.stacks7
# ---------
# ['toentry']
# ----------------------------------------------------------------------
# navigate_clickundefinedtunic.historicalsociety.entry7
# ---------
# ['tomap']
# ----------------------------------------------------------------------
# map_clickundefinedtunic.historicalsociety.entry7
# ---------
# ['tunic.humanecology']
# ----------------------------------------------------------------------
# person_clickbasictunic.humanecology.frontdesk7
# ---------
# ['worker']
# ----------------------------------------------------------------------
# object_clickclosetunic.humanecology.frontdesk7
# ---------
# ['businesscards']
# ----------------------------------------------------------------------
# navigate_clickundefinedtunic.humanecology.frontdesk8
# ---------
# ['tohallway']
# ----------------------------------------------------------------------
# map_clickundefinedtunic.humanecology.frontdesk8
# ---------
# ['tunic.drycleaner']
# ----------------------------------------------------------------------
# person_clickbasictunic.drycleaner.frontdesk8
# ---------
# ['worker']
# ----------------------------------------------------------------------
# object_hoverundefinedtunic.drycleaner.frontdesk8
# ---------
# ['logbook.page.bingo']
# ----------------------------------------------------------------------
# object_clickclosetunic.drycleaner.frontdesk8
# ---------
# ['logbook']
# ----------------------------------------------------------------------
# person_clickbasictunic.drycleaner.frontdesk9
# ---------
# ['worker']
# ----------------------------------------------------------------------
# map_clickundefinedtunic.drycleaner.frontdesk9
# ---------
# ['tunic.library']
# ----------------------------------------------------------------------
# person_clickbasictunic.library.frontdesk9
# ---------
# ['worker']
# ----------------------------------------------------------------------
# navigate_clickundefinedtunic.library.microfiche9
# ---------
# ['reader']
# ----------------------------------------------------------------------
# object_clickclosetunic.library.microfiche9
# ---------
# ['reader']
# ----------------------------------------------------------------------
# object_hoverbasictunic.library.frontdesk10
# ---------
# ['wellsbadge']
# ----------------------------------------------------------------------
# object_clickclosetunic.library.frontdesk10
# ---------
# ['wellsbadge']
# ----------------------------------------------------------------------
# person_clickbasictunic.library.frontdesk10
# ---------
# ['worker']
# ----------------------------------------------------------------------
# person_clickbasictunic.historicalsociety.frontdesk11
# ---------
# ['archivist']
# ----------------------------------------------------------------------
# observation_clickbasictunic.historicalsociety.stacks11
# ---------
# ['block']
# ----------------------------------------------------------------------
# object_hoverbasictunic.historicalsociety.stacks11
# ---------
# ['journals']
# ----------------------------------------------------------------------
# object_clickclosetunic.historicalsociety.stacks11
# ---------
# ['journals']
# ----------------------------------------------------------------------
# navigate_clickundefinedtunic.historicalsociety.stacks12
# ---------
# ['toentry']
# ----------------------------------------------------------------------
# map_clickundefinedtunic.historicalsociety.entry12
# ---------
# ['tunic.capitol_1']
# ----------------------------------------------------------------------
# navigate_clickundefinedtunic.capitol_1.hall12
# ---------
# ['chap2_finale_c']
# ----------------------------------------------------------------------
# checkpointbasictunic.capitol_1.hall12
# ---------
# ['chap2_finale_c']
# ----------------------------------------------------------------------
# navigate_clickundefinedtunic.capitol_1.hall13
# ---------
# ['toentry']
# ----------------------------------------------------------------------
# map_clickundefinedtunic.historicalsociety.entry13
# ---------
# ['tunic.historicalsociety']
# ----------------------------------------------------------------------
# observation_clickbasictunic.historicalsociety.cage14
# ---------
# ['lockeddoor']
# ----------------------------------------------------------------------
# object_hoverundefinedtunic.historicalsociety.entry15
# ---------
# ['directory.closeup.archivist']
# ----------------------------------------------------------------------
# object_clickclosetunic.historicalsociety.entry15
# ---------
# ['directory']
# ----------------------------------------------------------------------
# observation_clickbasictunic.historicalsociety.frontdesk15
# ---------
# ['key']
# ----------------------------------------------------------------------
# navigate_clickundefinedtunic.historicalsociety.frontdesk16
# ---------
# ['tostacks']
# ----------------------------------------------------------------------
# navigate_clickundefinedtunic.historicalsociety.stacks16
# ---------
# ['toentry']
# ----------------------------------------------------------------------
# navigate_clickundefinedtunic.historicalsociety.entry16
# ---------
# ['tobasement']
# ----------------------------------------------------------------------
# navigate_clickundefinedtunic.historicalsociety.basement16
# ---------
# ['tocage']
# ----------------------------------------------------------------------
# navigate_clickundefinedtunic.historicalsociety.cage17
# ---------
# ['tobasement']
# ----------------------------------------------------------------------
# cutscene_clickbasictunic.historicalsociety.basement17
# ---------
# ['savedteddy']
# ----------------------------------------------------------------------
# navigate_clickundefinedtunic.historicalsociety.basement17
# ---------
# ['toentry']
# ----------------------------------------------------------------------
# navigate_clickundefinedtunic.historicalsociety.stacks17
# ---------
# ['toentry']
# ----------------------------------------------------------------------
# navigate_clickundefinedtunic.historicalsociety.collection_flag17
# ---------
# ['gramps']
# ----------------------------------------------------------------------
# person_clickbasictunic.historicalsociety.collection_flag17
# ---------
# ['gramps']
# ----------------------------------------------------------------------
# person_clickbasictunic.historicalsociety.collection_flag18
# ---------
# ['gramps']
# ----------------------------------------------------------------------
# cutscene_clickbasictunic.historicalsociety.entry18
# ---------
# ['groupconvo_flag']
# ----------------------------------------------------------------------
# navigate_clickundefinedtunic.historicalsociety.basement18
# ---------
# ['toentry']
# ----------------------------------------------------------------------
# map_clickundefinedtunic.historicalsociety.entry18
# ---------
# ['tunic.wildlife']
# ----------------------------------------------------------------------
# object_hoverundefinedtunic.wildlife.center18
# ---------
# ['tracks.hub.deer']
# ----------------------------------------------------------------------
# object_clickclosetunic.wildlife.center18
# ---------
# ['tracks']
# ----------------------------------------------------------------------
# object_hoverbasictunic.wildlife.center18
# ---------
# ['tracks']
# ----------------------------------------------------------------------
# person_clickbasictunic.wildlife.center19
# ---------
# ['wells']
# ----------------------------------------------------------------------
# object_hoverbasictunic.wildlife.center19
# ---------
# ['tracks']
# ----------------------------------------------------------------------
# object_clickclosetunic.wildlife.center19
# ---------
# ['tracks']
# ----------------------------------------------------------------------
# map_clickundefinedtunic.wildlife.center19
# ---------
# ['tunic.flaghouse']
# ----------------------------------------------------------------------
# person_clickbasictunic.flaghouse.entry19
# ---------
# ['flag_girl']
# ----------------------------------------------------------------------
# object_clickbasictunic.flaghouse.entry19
# ---------
# ['colorbook']
# ----------------------------------------------------------------------
# object_clickclosetunic.flaghouse.entry19
# ---------
# ['colorbook']
# ----------------------------------------------------------------------
# navigate_clickundefinedtunic.flaghouse.entry20
# ---------
# ['tomap']
# ----------------------------------------------------------------------
# map_clickundefinedtunic.flaghouse.entry20
# ---------
# ['tunic.library']
# ----------------------------------------------------------------------
# person_clickbasictunic.library.frontdesk20
# ---------
# ['worker']
# ----------------------------------------------------------------------
# object_clickclosetunic.library.microfiche20
# ---------
# ['reader_flag']
# ----------------------------------------------------------------------
# person_clickbasictunic.library.frontdesk21
# ---------
# ['worker']
# ----------------------------------------------------------------------
# map_clickundefinedtunic.library.frontdesk21
# ---------
# ['tunic.historicalsociety']
# ----------------------------------------------------------------------
# person_clickbasictunic.historicalsociety.frontdesk21
# ---------
# ['archivist_glasses']
# ----------------------------------------------------------------------
# navigate_clickundefinedtunic.historicalsociety.stacks22
# ---------
# ['toentry']
# ----------------------------------------------------------------------
# navigate_clickundefinedtunic.historicalsociety.basement22
# ---------
# ['toentry']
# ----------------------------------------------------------------------
# map_clickundefinedtunic.historicalsociety.entry22
# ---------
# ['tunic.capitol_2']
# ----------------------------------------------------------------------
# navigate_clickundefinedtunic.capitol_2.hall22
# ---------
# ['chap4_finale_c']
# ----------------------------------------------------------------------
# checkpointbasictunic.capitol_2.hall22
# ---------
# ['chap4_finale_c']
# ----------------------------------------------------------------------
# object_clickbasictunic.historicalsociety.closet0
# ---------
# ['notebook']
# ----------------------------------------------------------------------
# observation_clickbasictunic.historicalsociety.entry1
# ---------
# ['block_tocollection']
# ----------------------------------------------------------------------
# object_hoverbasictunic.historicalsociety.entry1
# ---------
# ['boss']
# ----------------------------------------------------------------------
# observation_clickbasictunic.historicalsociety.stacks3
# ---------
# ['outtolunch']
# ----------------------------------------------------------------------
# object_hoverbasictunic.kohlcenter.halloffame3
# ---------
# ['plaque']
# ----------------------------------------------------------------------
# observation_clickbasictunic.historicalsociety.stacks5
# ---------
# ['outtolunch']
# ----------------------------------------------------------------------
# map_clickundefinedtunic.historicalsociety.entry5
# ---------
# ['tunic.kohlcenter']
# ----------------------------------------------------------------------
# object_clickbasictunic.kohlcenter.halloffame5
# ---------
# ['plaque']
# ----------------------------------------------------------------------
# object_clickclosetunic.kohlcenter.halloffame5
# ---------
# ['plaque']
# ----------------------------------------------------------------------
# map_hoverbasictunic.kohlcenter.halloffame5
# ---------
# ['tunic.capitol_0']
# ----------------------------------------------------------------------
# map_clickundefinedtunic.kohlcenter.halloffame5
# ---------
# ['tunic.historicalsociety']
# ----------------------------------------------------------------------
# observation_clickbasictunic.historicalsociety.closet_dirty6
# ---------
# ['photo']
# ----------------------------------------------------------------------
# object_hoverbasictunic.drycleaner.frontdesk8
# ---------
# ['logbook']
# ----------------------------------------------------------------------
# object_clickclosetunic.library.microfiche10
# ---------
# ['reader']
# ----------------------------------------------------------------------
# person_clickbasictunic.humanecology.frontdesk11
# ---------
# ['worker']
# ----------------------------------------------------------------------
# map_clickundefinedtunic.humanecology.frontdesk11
# ---------
# ['tunic.capitol_1']
# ----------------------------------------------------------------------
# person_clickbasictunic.capitol_1.hall11
# ---------
# ['boss']
# ----------------------------------------------------------------------
# navigate_clickundefinedtunic.kohlcenter.halloffame11
# ---------
# ['toentry']
# ----------------------------------------------------------------------
# map_hoverbasictunic.kohlcenter.halloffame11
# ---------
# ['tunic.capitol_1']
# ----------------------------------------------------------------------
# map_clickundefinedtunic.kohlcenter.halloffame11
# ---------
# ['tunic.historicalsociety']
# ----------------------------------------------------------------------
# person_clickbasictunic.historicalsociety.closet_dirty11
# ---------
# ['gramps']
# ----------------------------------------------------------------------
# observation_clickbasictunic.historicalsociety.basement11
# ---------
# ['janitor']
# ----------------------------------------------------------------------
# object_hoverbasictunic.historicalsociety.collection11
# ---------
# ['tunic']
# ----------------------------------------------------------------------
# object_hoverundefinedtunic.historicalsociety.collection11
# ---------
# ['tunic.hub.slip']
# ----------------------------------------------------------------------
# object_clickclosetunic.historicalsociety.collection11
# ---------
# ['tunic']
# ----------------------------------------------------------------------
# navigate_clickundefinedtunic.historicalsociety.basement12
# ---------
# ['toentry']
# ----------------------------------------------------------------------
# navigate_clickundefinedtunic.library.frontdesk13
# ---------
# ['toentry']
# ----------------------------------------------------------------------
# map_clickundefinedtunic.library.frontdesk13
# ---------
# ['tunic.historicalsociety']
# ----------------------------------------------------------------------
# observation_clickbasictunic.historicalsociety.stacks14
# ---------
# ['outtolunch']
# ----------------------------------------------------------------------
# navigate_clickundefinedtunic.historicalsociety.collection14
# ---------
# ['toentry']
# ----------------------------------------------------------------------
# map_clickundefinedtunic.historicalsociety.entry14
# ---------
# ['tunic.library']
# ----------------------------------------------------------------------
# person_clickbasictunic.library.frontdesk14
# ---------
# ['worker']
# ----------------------------------------------------------------------
# navigate_clickundefinedtunic.library.microfiche14
# ---------
# ['tofrontdesk']
# ----------------------------------------------------------------------
# map_clickundefinedtunic.library.frontdesk14
# ---------
# ['tunic.capitol_2']
# ----------------------------------------------------------------------
# person_clickbasictunic.capitol_2.hall14
# ---------
# ['boss']
# ----------------------------------------------------------------------
# map_hoverbasictunic.capitol_2.hall14
# ---------
# ['toentry']
# ----------------------------------------------------------------------
# map_clickundefinedtunic.capitol_2.hall14
# ---------
# ['tunic.kohlcenter']
# ----------------------------------------------------------------------
# navigate_clickundefinedtunic.kohlcenter.halloffame14
# ---------
# ['toentry']
# ----------------------------------------------------------------------
# map_clickundefinedtunic.kohlcenter.halloffame14
# ---------
# ['tunic.drycleaner']
# ----------------------------------------------------------------------
# person_clickbasictunic.drycleaner.frontdesk14
# ---------
# ['worker']
# ----------------------------------------------------------------------
# object_hoverbasictunic.drycleaner.frontdesk14
# ---------
# ['logbook']
# ----------------------------------------------------------------------
# object_clickbasictunic.drycleaner.frontdesk14
# ---------
# ['logbook']
# ----------------------------------------------------------------------
# object_clickclosetunic.drycleaner.frontdesk14
# ---------
# ['logbook']
# ----------------------------------------------------------------------
# map_clickundefinedtunic.drycleaner.frontdesk14
# ---------
# ['tunic.historicalsociety']
# ----------------------------------------------------------------------
# object_hoverbasictunic.flaghouse.entry19
# ---------
# ['colorbook']
# ----------------------------------------------------------------------
# object_hoverbasictunic.library.microfiche20
# ---------
# ['reader_flag']
# ----------------------------------------------------------------------
# object_hoverbasictunic.historicalsociety.closet0
# ---------
# ['notebook']
# ----------------------------------------------------------------------
# object_hoverbasictunic.historicalsociety.entry2
# ---------
# ['directory']
# ----------------------------------------------------------------------
# object_clickclosetunic.historicalsociety.entry2
# ---------
# ['directory']
# ----------------------------------------------------------------------
# person_clickbasictunic.capitol_0.hall5
# ---------
# ['boss']
# ----------------------------------------------------------------------
# object_hoverbasictunic.library.microfiche9
# ---------
# ['reader']
# ----------------------------------------------------------------------
# object_hoverbasictunic.library.microfiche11
# ---------
# ['reader']
# ----------------------------------------------------------------------
# object_clickclosetunic.library.microfiche11
# ---------
# ['reader']
# ----------------------------------------------------------------------
# person_clickbasictunic.historicalsociety.basement13
# ---------
# ['gramps']
# ----------------------------------------------------------------------
# object_hoverbasictunic.historicalsociety.entry15
# ---------
# ['directory']
# ----------------------------------------------------------------------
# observation_clickbasictunic.historicalsociety.cage15
# ---------
# ['lockeddoor']
# ----------------------------------------------------------------------
# observation_clickbasictunic.historicalsociety.closet_dirty15
# ---------
# ['photo']
# ----------------------------------------------------------------------
# map_clickundefinedtunic.historicalsociety.entry21
# ---------
# ['tunic.library']
# ----------------------------------------------------------------------
# object_hoverbasictunic.library.microfiche21
# ---------
# ['reader_flag']
# ----------------------------------------------------------------------
# object_clickclosetunic.library.microfiche21
# ---------
# ['reader_flag']
# ----------------------------------------------------------------------
# navigate_clickundefinedtunic.historicalsociety.collection_flag22
# ---------
# ['toentry']
# ----------------------------------------------------------------------

# %%
test_df=sample_data_uni

# %%
len(fqid_dict)
# Out:
# 160

# %%
len(test_df['combine'].unique())
# Out:
# 279

# %%
len(test_df['combine'])
# Out:
# 541

# %%
#getting the index value from the fqid_data after mapping the values with the values in fqid_dict
#where extracted_fqid is null
null_fqid_data_ind=fqid_data[fqid_data['extracted_fqid'].isna()]['combine'].map(fqid_dict).index

# %%
#assigning the values to the combine_copy at the null_fqid_data_ind index values with the 
#combine values by mapping with fqid_dict dictionary where extracted_fqid column has null values
fqid_data['combine_copy'].iloc[null_fqid_data_ind]=fqid_data[fqid_data['extracted_fqid'].isna()]['combine'].map(fqid_dict)

# %%
fqid_data.head()
# Out:
#    level  index      event_name   name    fqid  \
# 0      0      0  cutscene_click  basic   intro
# 1      0      1    person_click  basic  gramps
# 2      0      2    person_click  basic  gramps
# 3      0      3    person_click  basic  gramps
# 4      0      4    person_click  basic  gramps
#
#                         room_fqid  \
# 0  tunic.historicalsociety.closet
# 1  tunic.historicalsociety.closet
# 2  tunic.historicalsociety.closet
# 3  tunic.historicalsociety.closet
# 4  tunic.historicalsociety.closet
#
#                                            text_fqid extracted_fqid  \
# 0               tunic.historicalsociety.closet.intro          intro
# 1  tunic.historicalsociety.closet.gramps.intro_0_...         gramps
# 2  tunic.historicalsociety.closet.gramps.intro_0_...         gramps
# 3  tunic.historicalsociety.closet.gramps.intro_0_...         gramps
# 4  tunic.historicalsociety.closet.gramps.intro_0_...         gramps
#
#                                  extracted_text_fqid  \
# 0               tunic.historicalsociety.closet.intro
# 1  tunic.historicalsociety.closet.gramps.intro_0_...
# 2  tunic.historicalsociety.closet.gramps.intro_0_...
# 3  tunic.historicalsociety.closet.gramps.intro_0_...
# 4  tunic.historicalsociety.closet.gramps.intro_0_...
#
#                                              combine combine_copy
# 0  cutscene_clickbasictunic.historicalsociety.clo...        intro
# 1   person_clickbasictunic.historicalsociety.closet0       gramps
# 2   person_clickbasictunic.historicalsociety.closet0       gramps
# 3   person_clickbasictunic.historicalsociety.closet0       gramps
# 4   person_clickbasictunic.historicalsociety.closet0       gramps

# %%
#getting the index of fqid_data where extracted_text_fqid is null and combine_copy is not null
cc_nn_index=fqid_data[fqid_data['extracted_text_fqid'].isna()&(fqid_data['combine_copy'].isna()==False)].index

# %%
#assigning the values of extracted_text_fqid to the newly created column extracted_text_fqid_copy 
fqid_data['extracted_text_fqid_copy']=fqid_data['extracted_text_fqid']

# %%
#assigning the combined values of room_fqid, combine_copy with the index values in cc_nn_index
#to the extracted_text_fqid_copy column at the index cc_nn_index
fqid_data['extracted_text_fqid_copy'].iloc[cc_nn_index]=fqid_data['room_fqid'].iloc[cc_nn_index]+'.'+fqid_data['combine_copy'].iloc[cc_nn_index]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
fqid_data.isnull().sum()
# Out:
# level                          0
# index                          0
# event_name                     0
# name                           0
# fqid                        1223
# room_fqid                      0
# text_fqid                   2566
# extracted_fqid              1223
# extracted_text_fqid         1147
# combine                        0
# combine_copy                1015
# extracted_text_fqid_copy     939
# dtype: int64

# %%
fqid_data.head()
# Out:
#    level  index      event_name   name    fqid  \
# 0      0      0  cutscene_click  basic   intro
# 1      0      1    person_click  basic  gramps
# 2      0      2    person_click  basic  gramps
# 3      0      3    person_click  basic  gramps
# 4      0      4    person_click  basic  gramps
#
#                         room_fqid  \
# 0  tunic.historicalsociety.closet
# 1  tunic.historicalsociety.closet
# 2  tunic.historicalsociety.closet
# 3  tunic.historicalsociety.closet
# 4  tunic.historicalsociety.closet
#
#                                            text_fqid extracted_fqid  \
# 0               tunic.historicalsociety.closet.intro          intro
# 1  tunic.historicalsociety.closet.gramps.intro_0_...         gramps
# 2  tunic.historicalsociety.closet.gramps.intro_0_...         gramps
# 3  tunic.historicalsociety.closet.gramps.intro_0_...         gramps
# 4  tunic.historicalsociety.closet.gramps.intro_0_...         gramps
#
#                                  extracted_text_fqid  \
# 0               tunic.historicalsociety.closet.intro
# 1  tunic.historicalsociety.closet.gramps.intro_0_...
# 2  tunic.historicalsociety.closet.gramps.intro_0_...
# 3  tunic.historicalsociety.closet.gramps.intro_0_...
# 4  tunic.historicalsociety.closet.gramps.intro_0_...
#
#                                              combine combine_copy  \
# 0  cutscene_clickbasictunic.historicalsociety.clo...        intro
# 1   person_clickbasictunic.historicalsociety.closet0       gramps
# 2   person_clickbasictunic.historicalsociety.closet0       gramps
# 3   person_clickbasictunic.historicalsociety.closet0       gramps
# 4   person_clickbasictunic.historicalsociety.closet0       gramps
#
#                             extracted_text_fqid_copy
# 0               tunic.historicalsociety.closet.intro
# 1  tunic.historicalsociety.closet.gramps.intro_0_...
# 2  tunic.historicalsociety.closet.gramps.intro_0_...
# 3  tunic.historicalsociety.closet.gramps.intro_0_...
# 4  tunic.historicalsociety.closet.gramps.intro_0_...

# %%
#checking the records where extracted_text_fqid_copy is not null and combine_copy is null
fqid_data[(fqid_data['extracted_text_fqid_copy'].isna()==False)&(fqid_data['combine_copy'].isna())]
# Out:
#       level  index          event_name   name fqid  \
# 23        0     23  notification_click  basic  NaN
# 65        2     65  notification_click  basic  NaN
# 66        2     66  notification_click  basic  NaN
# 112       3    112  notification_click  basic  NaN
# 113       3    113  notification_click  basic  NaN
# ...     ...    ...                 ...    ...  ...
# 3694     21    972  notification_click  basic  NaN
# 3695     21    973  notification_click  basic  NaN
# 3700     21    978  notification_click  basic  NaN
# 3701     21    979  notification_click  basic  NaN
# 3702     21    980  notification_click  basic  NaN
#
#                                room_fqid  \
# 23        tunic.historicalsociety.closet
# 65    tunic.historicalsociety.collection
# 66    tunic.historicalsociety.collection
# 112          tunic.kohlcenter.halloffame
# 113          tunic.kohlcenter.halloffame
# ...                                  ...
# 3694      tunic.historicalsociety.stacks
# 3695      tunic.historicalsociety.stacks
# 3700      tunic.historicalsociety.stacks
# 3701      tunic.historicalsociety.stacks
# 3702      tunic.historicalsociety.stacks
#
#                                               text_fqid extracted_fqid  \
# 23              tunic.historicalsociety.closet.notebook            NaN
# 65        tunic.historicalsociety.collection.tunic.slip            NaN
# 66        tunic.historicalsociety.collection.tunic.slip            NaN
# 112        tunic.kohlcenter.halloffame.plaque.face.date            NaN
# 113        tunic.kohlcenter.halloffame.plaque.face.date            NaN
# ...                                                 ...            ...
# 3694  tunic.historicalsociety.stacks.journals_flag.p...            NaN
# 3695  tunic.historicalsociety.stacks.journals_flag.p...            NaN
# 3700  tunic.historicalsociety.stacks.journals_flag.p...            NaN
# 3701  tunic.historicalsociety.stacks.journals_flag.p...            NaN
# 3702  tunic.historicalsociety.stacks.journals_flag.p...            NaN
#
#                                     extracted_text_fqid  \
# 23              tunic.historicalsociety.closet.notebook
# 65        tunic.historicalsociety.collection.tunic.slip
# 66        tunic.historicalsociety.collection.tunic.slip
# 112        tunic.kohlcenter.halloffame.plaque.face.date
# 113        tunic.kohlcenter.halloffame.plaque.face.date
# ...                                                 ...
# 3694  tunic.historicalsociety.stacks.journals_flag.p...
# 3695  tunic.historicalsociety.stacks.journals_flag.p...
# 3700  tunic.historicalsociety.stacks.journals_flag.p...
# 3701  tunic.historicalsociety.stacks.journals_flag.p...
# 3702  tunic.historicalsociety.stacks.journals_flag.p...
#
#                                                 combine combine_copy  \
# 23    notification_clickbasictunic.historicalsociety...          NaN
# 65    notification_clickbasictunic.historicalsociety...          NaN
# 66    notification_clickbasictunic.historicalsociety...          NaN
# 112   notification_clickbasictunic.kohlcenter.hallof...          NaN
# 113   notification_clickbasictunic.kohlcenter.hallof...          NaN
# ...                                                 ...          ...
# 3694  notification_clickbasictunic.historicalsociety...          NaN
# 3695  notification_clickbasictunic.historicalsociety...          NaN
# 3700  notification_clickbasictunic.historicalsociety...          NaN
# 3701  notification_clickbasictunic.historicalsociety...          NaN
# 3702  notification_clickbasictunic.historicalsociety...          NaN
#
#                                extracted_text_fqid_copy
# 23              tunic.historicalsociety.closet.notebook
# 65        tunic.historicalsociety.collection.tunic.slip
# 66        tunic.historicalsociety.collection.tunic.slip
# 112        tunic.kohlcenter.halloffame.plaque.face.date
# 113        tunic.kohlcenter.halloffame.plaque.face.date
# ...                                                 ...
# 3694  tunic.historicalsociety.stacks.journals_flag.p...
# 3695  tunic.historicalsociety.stacks.journals_flag.p...
# 3700  tunic.historicalsociety.stacks.journals_flag.p...
# 3701  tunic.historicalsociety.stacks.journals_flag.p...
# 3702  tunic.historicalsociety.stacks.journals_flag.p...
#
# [76 rows x 12 columns]

# %%
#assigning the values in combine_copy of fqid_data to fqid column in data_frame
data_frame['fqid']=fqid_data['combine_copy']

# %%
fqid_data['extracted_text_fqid_copy'].str.split('.').str[3:]
# Out:
# 0                      [intro]
# 1       [gramps, intro_0_cs_0]
# 2       [gramps, intro_0_cs_0]
# 3       [gramps, intro_0_cs_0]
# 4       [gramps, intro_0_cs_0]
#                  ...
# 3723         [tunic, wildlife]
# 3724        [tunic, capitol_2]
# 3725        [tunic, capitol_2]
# 3726          [chap4_finale_c]
# 3727          [chap4_finale_c]
# Name: extracted_text_fqid_copy, Length: 3728, dtype: object

# %%
#assigning the values in extracted_text_fqid_copy of fqid_data to text_fqid column in data_frame
data_frame['text_fqid']=fqid_data['extracted_text_fqid_copy']

# %%
data_frame.head()
# Out:
#           session_id  index  elapsed_time      event_name   name  level  page  \
# 0  20090109393214576      0             0  cutscene_click  basic      0  -1.0
# 1  20090109393214576      1          1965    person_click  basic      0  -1.0
# 2  20090109393214576      2          3614    person_click  basic      0  -1.0
# 3  20090109393214576      3          5330    person_click  basic      0  -1.0
# 4  20090109393214576      4          6397    person_click  basic      0  -1.0
#
#    room_coor_x  room_coor_y  screen_coor_x  ...  hover_duration  \
# 0  -413.991405    75.685314          380.0  ...             0.0
# 1  -105.991405   -63.314686          688.0  ...             0.0
# 2  -418.991405    47.685314          375.0  ...             0.0
# 3  -110.991405   -57.314686          683.0  ...             0.0
# 4  -110.991405   -57.314686          683.0  ...             0.0
#
#                             text    fqid                       room_fqid  \
# 0                      undefined   intro  tunic.historicalsociety.closet
# 1  Whatcha doing over there, Jo?  gramps  tunic.historicalsociety.closet
# 2         Just talking to Teddy.  gramps  tunic.historicalsociety.closet
# 3     I gotta run to my meeting!  gramps  tunic.historicalsociety.closet
# 4            Can I come, Gramps?  gramps  tunic.historicalsociety.closet
#
#                                            text_fqid fullscreen  hq  music  \
# 0               tunic.historicalsociety.closet.intro          0   0      1
# 1  tunic.historicalsociety.closet.gramps.intro_0_...          0   0      1
# 2  tunic.historicalsociety.closet.gramps.intro_0_...          0   0      1
# 3  tunic.historicalsociety.closet.gramps.intro_0_...          0   0      1
# 4  tunic.historicalsociety.closet.gramps.intro_0_...          0   0      1
#
#    level_group session_level
# 0          0-4             0
# 1          0-4             0
# 2          0-4             0
# 3          0-4             0
# 4          0-4             0
#
# [5 rows x 21 columns]

# %%
#re-checking the null values in the data frame
data_frame.isnull().sum()
# Out:
# session_id           0
# index                0
# elapsed_time         0
# event_name           0
# name                 0
# level                0
# page                 0
# room_coor_x          0
# room_coor_y          0
# screen_coor_x        0
# screen_coor_y        0
# hover_duration       0
# text              2566
# fqid              1015
# room_fqid            0
# text_fqid          939
# fullscreen           0
# hq                   0
# music                0
# level_group          0
# session_level        0
# dtype: int64

# %%
#replacing the remaining null values in the fqid and text_fqid column with the string value 'Missing'

# %%
#checking whether missing exists in fqid column
'missing' in data_frame['fqid'].unique()
# Out:
# False

# %%
'Missing' in data_frame['fqid'].unique()
# Out:
# False

# %%
#checking whether missing exists in text_fqid column
'missing' in data_frame['text_fqid'].unique()
# Out:
# False

# %%
'Missing' in data_frame['text_fqid'].unique()
# Out:
# False

# %%
#replace the null values in fqid column with 'Missing' value

# %%
data_frame['fqid']=data_frame['fqid'].fillna('Missing')

# %%
data_frame['fqid']=data_frame['fqid'].str.split('.').str[0]

# %%
#replace the null values in text_fqid column with 'Missing' value

# %%
data_frame['text_fqid']=data_frame['text_fqid'].fillna('Missing')

# %%
data_frame['text_fqid']=data_frame['room_fqid']+'.'+data_frame['fqid']

# %%
#re-check the null value count
data_frame.isnull().sum()
# Out:
# session_id           0
# index                0
# elapsed_time         0
# event_name           0
# name                 0
# level                0
# page                 0
# room_coor_x          0
# room_coor_y          0
# screen_coor_x        0
# screen_coor_y        0
# hover_duration       0
# text              2566
# fqid                 0
# room_fqid            0
# text_fqid            0
# fullscreen           0
# hq                   0
# music                0
# level_group          0
# session_level        0
# dtype: int64

# %%
#removing the redudant columns such as 'text','session_id'

# %%
data_frame=data_frame.drop(['text','session_id'],axis=1)

# %%
data_frame.head()
# Out:
#    index  elapsed_time      event_name   name  level  page  room_coor_x  \
# 0      0             0  cutscene_click  basic      0  -1.0  -413.991405
# 1      1          1965    person_click  basic      0  -1.0  -105.991405
# 2      2          3614    person_click  basic      0  -1.0  -418.991405
# 3      3          5330    person_click  basic      0  -1.0  -110.991405
# 4      4          6397    person_click  basic      0  -1.0  -110.991405
#
#    room_coor_y  screen_coor_x  screen_coor_y  hover_duration    fqid  \
# 0    75.685314          380.0          259.0             0.0   intro
# 1   -63.314686          688.0          398.0             0.0  gramps
# 2    47.685314          375.0          287.0             0.0  gramps
# 3   -57.314686          683.0          392.0             0.0  gramps
# 4   -57.314686          683.0          392.0             0.0  gramps
#
#                         room_fqid                              text_fqid  \
# 0  tunic.historicalsociety.closet   tunic.historicalsociety.closet.intro
# 1  tunic.historicalsociety.closet  tunic.historicalsociety.closet.gramps
# 2  tunic.historicalsociety.closet  tunic.historicalsociety.closet.gramps
# 3  tunic.historicalsociety.closet  tunic.historicalsociety.closet.gramps
# 4  tunic.historicalsociety.closet  tunic.historicalsociety.closet.gramps
#
#    fullscreen  hq  music level_group  session_level
# 0           0   0      1         0-4              0
# 1           0   0      1         0-4              0
# 2           0   0      1         0-4              0
# 3           0   0      1         0-4              0
# 4           0   0      1         0-4              0

# %% [markdown]
# ### Label Encoding

# %% [markdown]
#  There are certain object columns which should be encoded into numerical values.

# %%
#differentiating the columns
object_cols=[]
numeric_cols=[]
for cols in data_frame.columns:
    if data_frame[cols].dtype=='O':
        object_cols.append(cols)
    else:
        try:
            data_frame[cols].astype(int)
            numeric_cols.append(cols)
        except:
            pass

# %%
object_cols
# Out:
# ['event_name', 'name', 'fqid', 'room_fqid', 'text_fqid', 'level_group']

# %%
numeric_cols
# Out:
# ['index',
#  'elapsed_time',
#  'level',
#  'page',
#  'room_coor_x',
#  'room_coor_y',
#  'screen_coor_x',
#  'screen_coor_y',
#  'hover_duration',
#  'fullscreen',
#  'hq',
#  'music',
#  'session_level']

# %% [markdown]
# Working on the column names in object_cols list

# %%
object_data=data_frame[object_cols]

# %%
object_data.head()
# Out:
#        event_name   name    fqid                       room_fqid  \
# 0  cutscene_click  basic   intro  tunic.historicalsociety.closet
# 1    person_click  basic  gramps  tunic.historicalsociety.closet
# 2    person_click  basic  gramps  tunic.historicalsociety.closet
# 3    person_click  basic  gramps  tunic.historicalsociety.closet
# 4    person_click  basic  gramps  tunic.historicalsociety.closet
#
#                                text_fqid level_group
# 0   tunic.historicalsociety.closet.intro         0-4
# 1  tunic.historicalsociety.closet.gramps         0-4
# 2  tunic.historicalsociety.closet.gramps         0-4
# 3  tunic.historicalsociety.closet.gramps         0-4
# 4  tunic.historicalsociety.closet.gramps         0-4

# %%
def label_encoding(col_name,df):
    ranking=df[col_name].value_counts().index
    mapping={i:k for k,i in enumerate(ranking,0)}
    return df[col_name].map(mapping)

# %%
for col_name in object_data.columns:
    object_data[col_name]=label_encoding(col_name,object_data)
# Out:
# /var/folders/4b/082wp8yj1vdb15yd5756bphm0000gn/T/ipykernel_13490/1270690668.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   object_data[col_name]=label_encoding(col_name,object_data)

# %%
object_data.head()
# Out:
#    event_name  name  fqid  room_fqid  text_fqid  level_group
# 0           3     0    63         14        116            2
# 1           1     0     6         14         61            2
# 2           1     0     6         14         61            2
# 3           1     0     6         14         61            2
# 4           1     0     6         14         61            2

# %% [markdown]
# Working on Numerical columns

# %%
numeric_cols
# Out:
# ['index',
#  'elapsed_time',
#  'level',
#  'page',
#  'room_coor_x',
#  'room_coor_y',
#  'screen_coor_x',
#  'screen_coor_y',
#  'hover_duration',
#  'fullscreen',
#  'hq',
#  'music',
#  'session_level']

# %%
num_data=data_frame[numeric_cols]

# %%
num_data.head()
# Out:
#    index  elapsed_time  level  page  room_coor_x  room_coor_y  screen_coor_x  \
# 0      0             0      0  -1.0  -413.991405    75.685314          380.0
# 1      1          1965      0  -1.0  -105.991405   -63.314686          688.0
# 2      2          3614      0  -1.0  -418.991405    47.685314          375.0
# 3      3          5330      0  -1.0  -110.991405   -57.314686          683.0
# 4      4          6397      0  -1.0  -110.991405   -57.314686          683.0
#
#    screen_coor_y  hover_duration  fullscreen  hq  music  session_level
# 0          259.0             0.0           0   0      1              0
# 1          398.0             0.0           0   0      1              0
# 2          287.0             0.0           0   0      1              0
# 3          392.0             0.0           0   0      1              0
# 4          392.0             0.0           0   0      1              0

# %%
from sklearn.preprocessing import StandardScaler

# %%
final_data_frame=pd.concat([object_data,num_data],axis=1)

# %%
final_data_frame.head()
# Out:
#    event_name  name  fqid  room_fqid  text_fqid  level_group  index  \
# 0           3     0    63         14        116            2      0
# 1           1     0     6         14         61            2      1
# 2           1     0     6         14         61            2      2
# 3           1     0     6         14         61            2      3
# 4           1     0     6         14         61            2      4
#
#    elapsed_time  level  page  room_coor_x  room_coor_y  screen_coor_x  \
# 0             0      0  -1.0  -413.991405    75.685314          380.0
# 1          1965      0  -1.0  -105.991405   -63.314686          688.0
# 2          3614      0  -1.0  -418.991405    47.685314          375.0
# 3          5330      0  -1.0  -110.991405   -57.314686          683.0
# 4          6397      0  -1.0  -110.991405   -57.314686          683.0
#
#    screen_coor_y  hover_duration  fullscreen  hq  music  session_level
# 0          259.0             0.0           0   0      1              0
# 1          398.0             0.0           0   0      1              0
# 2          287.0             0.0           0   0      1              0
# 3          392.0             0.0           0   0      1              0
# 4          392.0             0.0           0   0      1              0

# %%
scaler=StandardScaler()

# %%
transformed_data=scaler.fit_transform(final_data_frame)

# %%
final_input_data=pd.DataFrame(transformed_data)

# %%
final_input_data.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.572810 -0.912381  4.099225  1.821716  3.305951  2.012536 -1.630620
# 1 -0.342311 -0.912381 -0.300180  1.821716  1.273612  2.012536 -1.628188
# 2 -0.342311 -0.912381 -0.300180  1.821716  1.273612  2.012536 -1.625755
# 3 -0.342311 -0.912381 -0.300180  1.821716  1.273612  2.012536 -1.623323
# 4 -0.342311 -0.912381 -0.300180  1.821716  1.273612  2.012536 -1.620891
#
#          7         8         9         10        11        12        13  \
# 0 -0.993054 -1.937641 -0.187175 -0.825175  0.896769 -0.143707 -0.563536
# 1 -0.992109 -1.937641 -0.187175 -0.190921  0.254304  1.000591  0.242797
# 2 -0.991316 -1.937641 -0.187175 -0.835472  0.767351 -0.162283 -0.401109
# 3 -0.990490 -1.937641 -0.187175 -0.201217  0.282036  0.982015  0.207991
# 4 -0.989977 -1.937641 -0.187175 -0.201217  0.282036  0.982015  0.207991
#
#          14   15   16   17     18
# 0 -0.146064  0.0  0.0  0.0 -1.707
# 1 -0.146064  0.0  0.0  0.0 -1.707
# 2 -0.146064  0.0  0.0  0.0 -1.707
# 3 -0.146064  0.0  0.0  0.0 -1.707
# 4 -0.146064  0.0  0.0  0.0 -1.707

# %%
final_input_data.columns=final_data_frame.columns

# %%
final_input_data['session_level']=data_frame['session_level']

# %%
final_input_data.head()
# Out:
#    event_name      name      fqid  room_fqid  text_fqid  level_group  \
# 0    0.572810 -0.912381  4.099225   1.821716   3.305951     2.012536
# 1   -0.342311 -0.912381 -0.300180   1.821716   1.273612     2.012536
# 2   -0.342311 -0.912381 -0.300180   1.821716   1.273612     2.012536
# 3   -0.342311 -0.912381 -0.300180   1.821716   1.273612     2.012536
# 4   -0.342311 -0.912381 -0.300180   1.821716   1.273612     2.012536
#
#       index  elapsed_time     level      page  room_coor_x  room_coor_y  \
# 0 -1.630620     -0.993054 -1.937641 -0.187175    -0.825175     0.896769
# 1 -1.628188     -0.992109 -1.937641 -0.187175    -0.190921     0.254304
# 2 -1.625755     -0.991316 -1.937641 -0.187175    -0.835472     0.767351
# 3 -1.623323     -0.990490 -1.937641 -0.187175    -0.201217     0.282036
# 4 -1.620891     -0.989977 -1.937641 -0.187175    -0.201217     0.282036
#
#    screen_coor_x  screen_coor_y  hover_duration  fullscreen   hq  music  \
# 0      -0.143707      -0.563536       -0.146064         0.0  0.0    0.0
# 1       1.000591       0.242797       -0.146064         0.0  0.0    0.0
# 2      -0.162283      -0.401109       -0.146064         0.0  0.0    0.0
# 3       0.982015       0.207991       -0.146064         0.0  0.0    0.0
# 4       0.982015       0.207991       -0.146064         0.0  0.0    0.0
#
#    session_level
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0

# %%
final_input_data.shape
# Out:
# (3728, 19)

# %%
final_input_data.to_csv('data/clean_test_data.csv',index=False)
