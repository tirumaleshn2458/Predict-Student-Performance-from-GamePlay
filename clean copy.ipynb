# %%
import pandas as pd
import numpy as np

# %%
train_data=pd.read_csv('data/train.csv')

# %%
train_data_y=pd.read_csv('data/train_labels.csv')

# %%
#remove the rows with the levels from 19 to 22

# %%
train_data.head()
# Out:
#           session_id  index  elapsed_time      event_name   name  level  page  \
# 0  20090312431273200      0             0  cutscene_click  basic      0   NaN
# 1  20090312431273200      1          1323    person_click  basic      0   NaN
# 2  20090312431273200      2           831    person_click  basic      0   NaN
# 3  20090312431273200      3          1147    person_click  basic      0   NaN
# 4  20090312431273200      4          1863    person_click  basic      0   NaN
#
#    room_coor_x  room_coor_y  screen_coor_x  screen_coor_y  hover_duration  \
# 0  -413.991405  -159.314686          380.0          494.0             NaN
# 1  -413.991405  -159.314686          380.0          494.0             NaN
# 2  -413.991405  -159.314686          380.0          494.0             NaN
# 3  -413.991405  -159.314686          380.0          494.0             NaN
# 4  -412.991405  -159.314686          381.0          494.0             NaN
#
# ...

# %%
train_data['session_id']=train_data['session_id'].astype(str)

# %%
filtered_data=train_data[(train_data['level']>0)&(train_data['level']<19)].copy()

# %%
train_data_y.head()
# Out:
#              session_id  correct
# 0  20090312431273200_q1        1
# 1  20090312433251036_q1        0
# 2  20090312455206810_q1        1
# 3  20090313091715820_q1        0
# 4  20090313571836404_q1        1

# %%
train_data_y['s_id']=train_data_y['session_id'].str.split('_q').str[0]
train_data_y['question']=train_data_y['session_id'].str.split('_q').str[1]

# %%
train_data_y.head()
# Out:
#              session_id  correct               s_id question
# 0  20090312431273200_q1        1  20090312431273200        1
# 1  20090312433251036_q1        0  20090312433251036        1
# 2  20090312455206810_q1        1  20090312455206810        1
# 3  20090313091715820_q1        0  20090313091715820        1
# 4  20090313571836404_q1        1  20090313571836404        1

# %%
train_data_y_copy=train_data_y.copy()
train_data_y_copy['session_id']=train_data_y['s_id']
train_data_y_copy['level']=train_data_y['question'].astype(int)
train_data_y_copy=train_data_y_copy[['session_id','level','correct']]

# %%
final_train_data=train_data.merge(train_data_y_copy,on=['session_id','level'])

# %%
final_train_data.head()
# Out:
#           session_id  index  elapsed_time          event_name       name  \
# 0  20090312431273200     28         28113      navigate_click  undefined
# 1  20090312431273200     29         32229  notification_click      basic
# 2  20090312431273200     30         33063  notification_click      basic
# 3  20090312431273200     31         34245  notification_click      basic
# 4  20090312431273200     32         36433        object_click      close
#
#    level  page  room_coor_x  room_coor_y  screen_coor_x  ...  hover_duration  \
# 0      1   NaN  -587.657879   -27.916913          441.0  ...             NaN
# 1      1   NaN  -182.558163    -1.906501          767.0  ...             NaN
# 2      1   NaN  -182.500704   -55.888296          767.0  ...             NaN
# 3      1   NaN  -182.486523   -55.883804          767.0  ...             NaN
# 4      1   NaN  -113.484832   241.116732          836.0  ...             NaN
#
# ...

# %%
final_train_data.isnull().sum()
# Out:
# session_id               0
# index                    0
# elapsed_time             0
# event_name               0
# name                     0
# level                    0
# page              20305214
# room_coor_x        1355570
# room_coor_y        1355570
# screen_coor_x      1355570
# screen_coor_y      1355570
# hover_duration    19424403
# text              12689873
# fqid               6367237
# room_fqid                0
# text_fqid         12689791
# fullscreen               0
# hq                       0
# music                    0
# level_group              0
# correct                  0
# dtype: int64

# %%
final_train_data[(final_train_data['room_coor_x']==0)&(final_train_data['room_coor_y']==0)]
# Out:
# Empty DataFrame
# Columns: [session_id, index, elapsed_time, event_name, name, level, page, room_coor_x, room_coor_y, screen_coor_x, screen_coor_y, hover_duration, text, fqid, room_fqid, text_fqid, fullscreen, hq, music, level_group, correct]
# Index: []
#
# [0 rows x 21 columns]

# %%
#increase the coors by 1
#make them as string
#encode them 

#same for the hover_duration
#check for the outcomes of correct column when there is a text or not. but, text has null value or not.

# %%
final_train_data['room_coor_x']=final_train_data['room_coor_x'].fillna(0)
final_train_data['room_coor_y']=final_train_data['room_coor_y'].fillna(0)
final_train_data['screen_coor_x']=final_train_data['screen_coor_x'].fillna(0)
final_train_data['screen_coor_y']=final_train_data['screen_coor_x'].fillna(0)

# %%
final_train_data['hover_duration']=final_train_data['hover_duration'].fillna(0)

# %%
final_train_data['text_fqid'][1]
# Out:
# 'tunic.historicalsociety.closet.retirement_letter.hub'

# %%
final_train_data['text_fqid'][2]
# Out:
# 'tunic.historicalsociety.closet.retirement_letter.hub'

# %%
final_train_data.head(50)
# Out:
#            session_id  index  elapsed_time          event_name       name  \
# 0   20090312431273200     28         28113      navigate_click  undefined
# 1   20090312431273200     29         32229  notification_click      basic
# 2   20090312431273200     30         33063  notification_click      basic
# 3   20090312431273200     31         34245  notification_click      basic
# 4   20090312431273200     32         36433        object_click      close
# 5   20090312431273200     33         36346      navigate_click  undefined
# 6   20090312431273200     34         36896      navigate_click  undefined
# 7   20090312431273200     35         37445      navigate_click  undefined
# 8   20090312431273200     36         39845      navigate_click  undefined
# 9   20090312431273200     37         41297   observation_click      basic
# 10  20090312431273200     38         41898      navigate_click  undefined
# 11  20090312431273200     39         43413      navigate_click  undefined
# ...

# %%
final_train_data.isnull().sum()
# Out:
# session_id               0
# index                    0
# elapsed_time             0
# event_name               0
# name                     0
# level                    0
# page              20305214
# room_coor_x              0
# room_coor_y              0
# screen_coor_x            0
# screen_coor_y            0
# hover_duration           0
# text              12689873
# fqid               6367237
# room_fqid                0
# text_fqid         12689791
# fullscreen               0
# hq                       0
# music                    0
# level_group              0
# correct                  0
# dtype: int64

# %%
#replacing null values

# %%
#for page

# %%
final_train_data_copy=final_train_data.copy()

# %%
final_train_data_copy['session_id'].unique()[:5]
# Out:
# array(['20090312431273200', '20090312433251036', '20090312455206810',
#        '20090313091715820', '20090313571836404'], dtype=object)

# %%
final_train_data_copy[final_train_data_copy['page'].isna()]
# Out:
#                  session_id  index  elapsed_time          event_name  \
# 0         20090312431273200     28         28113      navigate_click
# 1         20090312431273200     29         32229  notification_click
# 2         20090312431273200     30         33063  notification_click
# 3         20090312431273200     31         34245  notification_click
# 4         20090312431273200     32         36433        object_click
# ...                     ...    ...           ...                 ...
# 20732573  22100221145014656   1319       5057413        person_click
# 20732574  22100221145014656   1320       5059532        person_click
# 20732575  22100221145014656   1321       5061233        person_click
# 20732576  22100221145014656   1322       5065187        person_click
# 20732577  22100221145014656   1323       5071132        person_click
#
#                name  level  page  room_coor_x  room_coor_y  screen_coor_x  \
# ...

# %%
final_train_data_copy[['level','index','page']].dropna()
# Out:
#           level  index  page
# 776           2     60   0.0
# 777           2     61   0.0
# 914           6    209   1.0
# 915           6    210   1.0
# 916           6    211   1.0
# ...         ...    ...   ...
# 20732155     15    901   4.0
# 20732189     16    935   4.0
# 20732190     16    936   4.0
# 20732416     18   1162   5.0
# 20732417     18   1163   5.0
#
# [427364 rows x 3 columns]

# %%
final_train_data_copy['level_index']=final_train_data_copy['level'].astype(str)+final_train_data_copy['index'].astype(str)

# %%
final_train_data_copy['level_index'].head()
# Out:
# 0    128
# 1    129
# 2    130
# 3    131
# 4    132
# Name: level_index, dtype: object

# %%
non_null_page_data=final_train_data_copy[final_train_data_copy['page'].isna()==False]

# %%
page_dict=dict(zip(non_null_page_data['level_index'],non_null_page_data['page']))

# %%
final_train_data_copy['page_ref']=final_train_data_copy['level_index'].map(page_dict)

# %%
null_page_data=final_train_data_copy[final_train_data_copy['page'].isna()]
non_null_page_data=final_train_data_copy[final_train_data_copy['page'].isna()==False]

# %%
null_page_data['page_ref']=null_page_data['level_index'].map(page_dict)
# Out:
# /var/folders/4b/082wp8yj1vdb15yd5756bphm0000gn/T/ipykernel_3968/1739597491.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   null_page_data['page_ref']=null_page_data['level_index'].map(page_dict)

# %%
null_page_data['page'].isnull().sum()
# Out:
# 20305214

# %%
null_page_data['page_ref'].isnull().sum()
# Out:
# 339918

# %%
#machine learning model for imputing the values for page column

# %%
non_null_page_data.shape
# Out:
# (427364, 23)

# %%
null_page_data.shape
# Out:
# (20305214, 23)

# %%
#concat the non_null_page_data and null_page_data
page_data=pd.concat([non_null_page_data,null_page_data])

# %%
len(page_data['page'])-page_data['page'].isnull().sum()
# Out:
# 427364

# %%
page_data
# Out:
#                  session_id  index  elapsed_time      event_name   name  \
# 776       20090312433251036     60         60743  notebook_click   open
# 777       20090312433251036     61         61761  notebook_click  close
# 914       20090312433251036    209        351064  notebook_click   open
# 915       20090312433251036    210        354779  notebook_click  basic
# 916       20090312433251036    211        357947  notebook_click  close
# ...                     ...    ...           ...             ...    ...
# 20732573  22100221145014656   1319       5057413    person_click  basic
# 20732574  22100221145014656   1320       5059532    person_click  basic
# 20732575  22100221145014656   1321       5061233    person_click  basic
# 20732576  22100221145014656   1322       5065187    person_click  basic
# 20732577  22100221145014656   1323       5071132    person_click  basic
#
#           level  page  room_coor_x  room_coor_y  screen_coor_x  ...   fqid  \
# ...

# %%
page_data_train=final_train_data_copy[['index','level','page']][final_train_data_copy['page'].isna()==False]

# %%
page_data_train.head()
# Out:
#      index  level  page
# 776     60      2   0.0
# 777     61      2   0.0
# 914    209      6   1.0
# 915    210      6   1.0
# 916    211      6   1.0

# %%
page_data_test=page_data[['index','level','page_ref']][page_data['page_ref'].isna()==True]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# %%
def label_encoding(df,col_name):
    ranking=df[col_name].value_counts().index
    mapping={k:i for i,k in enumerate(ranking,0)}
    return df[col_name].map(mapping)

# %%
x=final_train_data_copy.drop(['page'],axis=1)[final_train_data_copy['page'].isna()==False]
x=x[['index','level']]
y=final_train_data_copy.iloc[x.index][['page']]
#x_test=page_data_test.drop(['page_ref'],axis=1)
#y_test=page_data_test[['page_ref']]

# %%
#x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.0)

# %%
model=RandomForestClassifier()

# %%
model.fit(x,y)
# Out:
# /var/folders/4b/082wp8yj1vdb15yd5756bphm0000gn/T/ipykernel_3968/1265173374.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(x,y)
# RandomForestClassifier()

# %%
page_data=final_train_data_copy[['index','level']]

# %%
final_train_data_copy['page_ref4']=model.predict(page_data)

# %%
final_train_data_copy

# %%
print('page==page_ref')
print(final_train_data_copy[(final_train_data_copy['page'].isna()==False)&(final_train_data_copy['page']==final_train_data_copy['page_ref'])].shape)
print('#page!=page_ref')
print(final_train_data_copy[(final_train_data_copy['page'].isna()==False)&(final_train_data_copy['page']!=final_train_data_copy['page_ref'])][['page','page_ref']].shape)
print('#page==page_ref4')
print(final_train_data_copy[(final_train_data_copy['page'].isna()==False)&(final_train_data_copy['page']==final_train_data_copy['page_ref4'])].shape)
print('#page!=page_ref4')
print(final_train_data_copy[(final_train_data_copy['page'].isna()==False)&(final_train_data_copy['page']!=final_train_data_copy['page_ref4'])].shape)
print('#page==page_ref_new1')
print(final_train_data_copy[(final_train_data_copy['page'].isna()==False)&(final_train_data_copy['page']==final_train_data_copy['page_ref_new2'])].shape)
print('#page!=page_ref_new1')
print(final_train_data_copy[(final_train_data_copy['page'].isna()==False)&(final_train_data_copy['page']!=final_train_data_copy['page_ref_new2'])].shape)
# Out:
# page==page_ref
# (400890, 27)
# #page!=page_ref
# (26474, 2)
# #page==page_ref4
# (400890, 27)
# #page!=page_ref4
# (26474, 27)
# #page==page_ref_new1
# (387972, 27)
# #page!=page_ref_new1
# (39392, 27)

# %%
#page!=page_ref
final_train_data_copy[(final_train_data_copy['page'].isna()==False)&(final_train_data_copy['page']!=final_train_data_copy['page_ref'])][['page','page_ref']].shape
# Out:
# (26474, 2)

# %%
#page==page_ref_new
final_train_data_copy[(final_train_data_copy['page'].isna()==False)&(final_train_data_copy['page']==final_train_data_copy['page_ref_new'])].shape
# Out:
# (400889, 25)

# %%
#page!=page_ref_new
final_train_data_copy[(final_train_data_copy['page'].isna()==False)&(final_train_data_copy['page']!=final_train_data_copy['page_ref_new'])].shape
# Out:
# (26475, 25)

# %%
final_train_data_copy['page_ref'].value_counts()
# Out:
# 1.0    98833
# 4.0    85756
# 0.0    71946
# 5.0    62428
# 3.0    61137
# 2.0    47320
# Name: page_ref, dtype: int64

# %%
final_train_data_copy['page_ref'].isnull().sum()
# Out:
# 20305158

# %%
non_null_page_data1[non_null_page_data1['page']==non_null_page_data1['page_ref']]
# Out:
# Empty DataFrame
# Columns: [session_id, index, elapsed_time, event_name, name, level, page, room_coor_x, room_coor_y, screen_coor_x, screen_coor_y, hover_duration, text, fqid, room_fqid, text_fqid, fullscreen, hq, music, level_group, correct, level_index, page_ref]
# Index: []
#
# [0 rows x 23 columns]

# %%
final_train_data_copy[final_train_data_copy['session_id']=='22100221145014656'].groupby('level')['index'].value_counts()
# Out:
# level  index
# 1      41       1
#        42       1
#        43       1
#        44       1
#        45       1
#                ..
# 18     1319     1
#        1320     1
#        1321     1
#        1322     1
#        1323     1
# Name: index, Length: 1225, dtype: int64

# %%
final_train_data_copy.groupby('level')['page'].unique()
# Out:
# level
# 1                              [nan, 0.0]
# 2                              [nan, 0.0]
# 3                              [nan, 0.0]
# 4                         [nan, 1.0, 0.0]
# 5                         [nan, 1.0, 0.0]
# 6                         [nan, 1.0, 0.0]
# 7                         [nan, 1.0, 0.0]
# 8                    [nan, 2.0, 1.0, 0.0]
# 9                    [nan, 2.0, 1.0, 0.0]
# 10              [nan, 3.0, 2.0, 1.0, 0.0]
# 11              [nan, 3.0, 2.0, 1.0, 0.0]
# 12              [nan, 3.0, 2.0, 1.0, 0.0]
# 13              [nan, 3.0, 2.0, 1.0, 0.0]
# 14         [nan, 4.0, 3.0, 2.0, 1.0, 0.0]
# 15         [nan, 4.0, 3.0, 2.0, 1.0, 0.0]
# 16         [nan, 4.0, 3.0, 2.0, 1.0, 0.0]
# 17         [nan, 4.0, 3.0, 2.0, 1.0, 0.0]
# 18    [nan, 5.0, 4.0, 3.0, 2.0, 1.0, 0.0]
# Name: page, dtype: object

# %%
level_4_data=final_train_data_copy[final_train_data_copy['level']==4]

# %%
level_4_data.groupby('index')['page'].value_counts().head(50)
# Out:
# index  page
# 17     1.0      1
# 18     1.0      2
# 19     1.0      1
# 32     1.0      1
# 33     1.0      1
# 38     1.0      1
# 39     1.0      1
# 57     1.0      2
# 58     1.0      2
# 59     0.0      2
# 60     1.0      2
# 61     0.0      1
# 62     1.0      1
# 64     1.0      1
# 65     1.0      1
# 67     1.0      2
# 68     1.0      3
# 69     1.0      3
# 70     1.0      3
# 71     1.0      1
# 85     1.0      1
# 86     1.0      1
# 88     1.0      1
# 89     1.0      6
# 90     1.0      7
# 91     1.0      6
#        0.0      2
# 92     1.0      9
# 93     1.0     17
# 94     1.0     19
#        0.0      1
# 95     1.0     15
#        0.0      1
# 96     1.0     19
#        0.0      1
# 97     1.0     25
#        0.0      2
# 98     1.0     31
#        0.0      1
# 99     1.0     36
# 100    1.0     38
#        0.0      1
# 101    1.0     42
#        0.0      4
# 102    1.0     43
#        0.0      3
# 103    1.0     58
#        0.0      3
# 104    1.0     78
# ...

# %%
len(final_train_data['session_id'].unique())
# Out:
# 23562

# %%
#level_4 impute

# %%
level_4_data_nn=level_4_data[level_4_data['page'].isna()==False]

# %%
l4_dict=dict(zip(level_4_data_nn['index'],level_4_data_nn['page']))

# %%
level_4_data['page_ref']=level_4_data['index'].map(l4_dict)
# Out:
# /var/folders/4b/082wp8yj1vdb15yd5756bphm0000gn/T/ipykernel_1043/2312695362.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   level_4_data['page_ref']=level_4_data['index'].map(l4_dict)

# %%
level_4_data[level_4_data['page'].isna()==False]['page'].value_counts()
# Out:
# 1.0    16287
# 0.0     1237
# Name: page, dtype: int64

# %%
level_4_data[(level_4_data['page'].isna()==False)&(level_4_data['page']!=level_4_data['page_ref'])]
# Out:
#                  session_id  index  elapsed_time      event_name   name  \
# 9440      20090315085850788    152        355631  notebook_click  close
# 11110     20090315170769824    140        218570  notebook_click  close
# 16968     20090317414400068    120        242500  notebook_click  basic
# 27837     20100008103581056    120        449550  notebook_click   open
# 41477     20100011394713344    144        174410  notebook_click  close
# ...                     ...    ...           ...             ...    ...
# 20657271  22090518383529716    160        459651  notebook_click  close
# 20674066  22090609530915296    180        570531  notebook_click  close
# 20683710  22090613301481920    175        203642  notebook_click  basic
# 20683711  22090613301481920    176        204856  notebook_click   next
# 20701904  22090617092908200    149        225670  notebook_click   next
#
#           level  page  room_coor_x  room_coor_y  screen_coor_x  ...  text  \
# ...

# %%
list1=list(np.sort(final_train_data_copy[(final_train_data_copy['level']==4)&(final_train_data_copy['page']==1)]['index'].unique()))

# %%
list2=list(np.sort(final_train_data_copy[(final_train_data_copy['level']==4)&(final_train_data_copy['page']==0)]['index'].unique()))

# %%
check=any(item in list1 for item in list2)

# %%
check
# Out:
# True

# %%
final_train_data_copy.corr()
# Out:
#                    index  elapsed_time     level      page  room_coor_x  \
# index           1.000000      0.068421  0.576493  0.264002    -0.052366
# elapsed_time    0.068421      1.000000  0.067189  0.070597    -0.007515
# level           0.576493      0.067189  1.000000  0.952067    -0.128668
# page            0.264002      0.070597  0.952067  1.000000    -0.009094
# room_coor_x    -0.052366     -0.007515 -0.128668 -0.009094     1.000000
# room_coor_y    -0.226941     -0.026572 -0.378233 -0.122258     0.062854
# screen_coor_x   0.015712     -0.001475  0.013674  0.003162     0.597559
# screen_coor_y   0.015712     -0.001475  0.013674  0.003162     0.597559
# hover_duration -0.000255      0.005452 -0.000348       NaN     0.000233
# fullscreen     -0.017283      0.009462 -0.000211  0.002773    -0.004704
# hq             -0.007608      0.005883 -0.003037 -0.001572    -0.001961
# music           0.019590     -0.002943  0.001768  0.004435     0.002386
# ...

# %%
#elapsed_time, event_name, name, level, coors, hover_duration,room_fqid

# %%
final_train_data['name'].unique()
# Out:
# array(['undefined', 'basic', 'close', 'open', 'prev', 'next'],
#       dtype=object)

# %%
test_data=pd.read_csv('data/test.csv')

# %%
final_train_data_copy=final_train_data.copy()

# %%
final_train_data_copy.head()
# Out:
#           session_id  index  elapsed_time          event_name       name  \
# 0  20090312431273200     28         28113      navigate_click  undefined
# 1  20090312431273200     29         32229  notification_click      basic
# 2  20090312431273200     30         33063  notification_click      basic
# 3  20090312431273200     31         34245  notification_click      basic
# 4  20090312431273200     32         36433        object_click      close
#
#    level  page  room_coor_x  room_coor_y  screen_coor_x  ...  hover_duration  \
# 0      1   NaN  -587.657879   -27.916913          441.0  ...             0.0
# 1      1   NaN  -182.558163    -1.906501          767.0  ...             0.0
# 2      1   NaN  -182.500704   -55.888296          767.0  ...             0.0
# 3      1   NaN  -182.486523   -55.883804          767.0  ...             0.0
# 4      1   NaN  -113.484832   241.116732          836.0  ...             0.0
#
# ...

# %%
final_train_data_copy[final_train_data_copy['text_fqid'].isna()!=True]['text_fqid'][1]
# Out:
# 'tunic.historicalsociety.closet.retirement_letter.hub'

# %%
final_train_data_copy['text_fqid'].str.split('.')[1]
# Out:
# ['tunic', 'historicalsociety', 'closet', 'retirement_letter', 'hub']

# %%
final_train_data_copy['page'].value_counts()
# Out:
# 1.0    98833
# 4.0    85756
# 0.0    71918
# 5.0    62428
# 3.0    61109
# 2.0    47320
# Name: page, dtype: int64

# %%
final_train_data_copy['level'].value_counts()
# Out:
# 18    3499163
# 6     2117796
# 11    1937208
# 16    1295082
# 7     1278207
# 15    1219497
# 17    1207881
# 3     1144768
# 9     1137748
# 2      992615
# 8      888584
# 13     823875
# 1      726590
# 5      668188
# 14     550829
# 10     449139
# 4      428040
# 12     367368
# Name: level, dtype: int64

# %%
final_train_data_copy[(final_train_data_copy['level']==2)&(final_train_data_copy['index']==28)]['page'].value_counts()
# Out:
# 0.0    2
# Name: page, dtype: int64

# %%
final_train_data_copy[final_train_data_copy['level']==2]['index'].value_counts()
# Out:
# 73      19180
# 74      19159
# 72      19130
# 75      19127
# 71      19025
#         ...
# 2809        1
# 2808        1
# 2807        1
# 2806        1
# 2606        1
# Name: index, Length: 2730, dtype: int64

# %%
final_train_data_copy1=final_train_data.copy()

# %%
final_train_data_copy1['room_fqid']

# %%
fqid_null_index=final_train_data_copy1[(final_train_data_copy1['fqid'].isna()==True)&
                       (final_train_data_copy1['text_fqid'].isna()==False)].index

# %%
final_train_data_copy1.iloc[fqid_null_index]['text_fqid'].str.split('.')
# Out:
# 1           [tunic, historicalsociety, closet, retirement_...
# 2           [tunic, historicalsociety, closet, retirement_...
# 3           [tunic, historicalsociety, closet, retirement_...
# 57          [tunic, historicalsociety, collection, tunic, ...
# 58          [tunic, historicalsociety, collection, tunic, ...
#                                   ...
# 20731908         [tunic, library, frontdesk, wellsbadge, hub]
# 20732081    [tunic, historicalsociety, stacks, journals, p...
# 20732082    [tunic, historicalsociety, stacks, journals, p...
# 20732083    [tunic, historicalsociety, stacks, journals, p...
# 20732528         [tunic, wildlife, center, tracks, hub, deer]
# Name: text_fqid, Length: 420476, dtype: object

# %%
final_train_data_copy1.iloc[fqid_null_index]['text_fqid'].str.split('.').str[3:]
# Out:
# 1             NaN
# 2             NaN
# 3             NaN
# 57            NaN
# 58            NaN
#             ...
# 20731908      NaN
# 20732081    bingo
# 20732082    bingo
# 20732083    bingo
# 20732528     deer
# Name: text_fqid, Length: 420476, dtype: object

# %%
final_train_data_copy1['fqid'].iloc[fqid_null_index]=final_train_data_copy1.iloc[fqid_null_index]['text_fqid'].str.split('.').str[3]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
final_train_data_copy1.iloc[fqid_null_index]['text_fqid'].str.split('.')
# Out:
# 1           [tunic, historicalsociety, closet, retirement_...
# 2           [tunic, historicalsociety, closet, retirement_...
# 3           [tunic, historicalsociety, closet, retirement_...
# 57          [tunic, historicalsociety, collection, tunic, ...
# 58          [tunic, historicalsociety, collection, tunic, ...
#                                   ...
# 20731908         [tunic, library, frontdesk, wellsbadge, hub]
# 20732081    [tunic, historicalsociety, stacks, journals, p...
# 20732082    [tunic, historicalsociety, stacks, journals, p...
# 20732083    [tunic, historicalsociety, stacks, journals, p...
# 20732528         [tunic, wildlife, center, tracks, hub, deer]
# Name: text_fqid, Length: 420476, dtype: object

# %%
final_train_data_copy1.head()
# Out:
#           session_id  index  elapsed_time          event_name       name  \
# 0  20090312431273200     28         28113      navigate_click  undefined
# 1  20090312431273200     29         32229  notification_click      basic
# 2  20090312431273200     30         33063  notification_click      basic
# 3  20090312431273200     31         34245  notification_click      basic
# 4  20090312431273200     32         36433        object_click      close
#
#    level  page  room_coor_x  room_coor_y  screen_coor_x  ...  hover_duration  \
# 0      1   NaN  -587.657879   -27.916913          441.0  ...             0.0
# 1      1   NaN  -182.558163    -1.906501          767.0  ...             0.0
# 2      1   NaN  -182.500704   -55.888296          767.0  ...             0.0
# 3      1   NaN  -182.486523   -55.883804          767.0  ...             0.0
# 4      1   NaN  -113.484832   241.116732          836.0  ...             0.0
#
# ...

# %%
final_train_data_copy1['text_fqid1']=final_train_data_copy1['room_fqid']+'.'+final_train_data_copy1['fqid']

# %%
final_train_data_copy1.head()
# Out:
#           session_id  index  elapsed_time          event_name       name  \
# 0  20090312431273200     28         28113      navigate_click  undefined
# 1  20090312431273200     29         32229  notification_click      basic
# 2  20090312431273200     30         33063  notification_click      basic
# 3  20090312431273200     31         34245  notification_click      basic
# 4  20090312431273200     32         36433        object_click      close
#
#    level  page  room_coor_x  room_coor_y  screen_coor_x  ...  \
# 0      1   NaN  -587.657879   -27.916913          441.0  ...
# 1      1   NaN  -182.558163    -1.906501          767.0  ...
# 2      1   NaN  -182.500704   -55.888296          767.0  ...
# 3      1   NaN  -182.486523   -55.883804          767.0  ...
# 4      1   NaN  -113.484832   241.116732          836.0  ...
#
#                                       text               fqid  \
# 0                                      NaN  retirement_letter
# ...

# %%
text_fqid_null_index=final_train_data_copy1[final_train_data_copy1['text_fqid'].isna()!=True].index

# %%
final_train_data_copy1.iloc[text_fqid_null_index].head(50)
# Out:
#             session_id  index  elapsed_time          event_name   name  level  \
# 1    20090312431273200     29         32229  notification_click  basic      1
# 2    20090312431273200     30         33063  notification_click  basic      1
# 3    20090312431273200     31         34245  notification_click  basic      1
# 9    20090312431273200     37         41297   observation_click  basic      1
# 13   20090312431273200     41         45062      cutscene_click  basic      1
# 14   20090312431273200     42         46046      cutscene_click  basic      1
# 15   20090312431273200     43         47362      cutscene_click  basic      1
# 16   20090312431273200     44         48112      cutscene_click  basic      1
# 17   20090312431273200     45         49514      cutscene_click  basic      1
# 18   20090312431273200     46         50144      cutscene_click  basic      1
# 19   20090312431273200     47         50794      cutscene_click  basic      1
# ...

# %%
final_train_data_copy1.isnull().sum()
# Out:
# session_id               0
# index                    0
# elapsed_time             0
# event_name               0
# name                     0
# level                    0
# page              20305214
# room_coor_x              0
# room_coor_y              0
# screen_coor_x            0
# screen_coor_y            0
# hover_duration           0
# text              12689873
# fqid               5946761
# room_fqid                0
# text_fqid         12689791
# fullscreen               0
# hq                       0
# music                    0
# level_group              0
# correct                  0
# text_fqid1         5946761
# dtype: int64

# %%
final_train_data_copy1[(final_train_data_copy1['room_fqid']=='tunic.historicalsociety.entry')&
                      (final_train_data_copy1['fqid']=='groupconvo')]['event_name'].value_counts()
# Out:
# cutscene_click    427180
# navigate_click     27359
# object_hover        1166
# Name: event_name, dtype: int64

# %%
final_train_data_copy1[(final_train_data_copy1['room_fqid']=='tunic.historicalsociety.entry')&
                      (final_train_data_copy1['event_name']=='navigate_click')]['fqid'].value_counts()
# Out:
# tomap                 173170
# tostacks              161787
# tobasement            140796
# tocollection           59829
# groupconvo_flag        59042
# tocollectionflag       50300
# directory              45086
# wells                  44343
# boss                   37127
# groupconvo             27359
# block_tomap2            2210
# block_tocollection      1367
# block_tomap1             917
# gramps                    65
# Name: fqid, dtype: int64

# %%
final_train_data_copy1[final_train_data_copy1['text_fqid']=='tunic.historicalsociety.collection.gramps.found']['event_name'].value_counts()
# Out:
# person_click    216279
# Name: event_name, dtype: int64

# %%
final_train_data_copy1['text_fqid'][1]
# Out:
# 'tunic.historicalsociety.closet.retirement_letter.hub'

# %%
final_train_data_copy1['text_fqid'].str.split('.').str[4:]
# Out:
# 0                NaN
# 1              [hub]
# 2              [hub]
# 3              [hub]
# 4                NaN
#               ...
# 20732573    [nodeer]
# 20732574    [nodeer]
# 20732575    [nodeer]
# 20732576    [nodeer]
# 20732577    [nodeer]
# Name: text_fqid, Length: 20732578, dtype: object
